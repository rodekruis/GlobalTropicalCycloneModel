# %% [markdown]
# For Random Forest model before and after ReducedOverfitting.
#
# The RMSE and Weighted RMSE estimation per bins for dataset where damaged values are greater than 10.

# %%
# %load_ext jupyter_black

# %%
import statistics
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, max_error

from utils import get_clean_dataset

# %%
df = get_clean_dataset()

# %%
df = df[df['DAM_perc_dmg'] > 10]
df
# Out:
#             typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 39       durian2006          128.785714             7.623810
# 40       durian2006          137.600000            10.846970
# 67       durian2006          236.800000            23.022917
# 79       durian2006          166.710000            11.723333
# 80       durian2006          218.475000            20.925000
# ...             ...                 ...                  ...
# 23423  vongfong2020          254.525000            23.410417
# 23461  vongfong2020          255.687500            21.612500
# 23877  vongfong2020          258.160000            18.825000
# 23958  vongfong2020          212.800000            15.002381
# 25363   meranti2016          281.550000            18.195833
#
#        HAZ_rainfall_max_24h  HAZ_v_max    HAZ_v_max_3  HAZ_dis_track_min  \
# 39                 4.991964  67.297247  304783.811133          16.034037
# 40                 5.338258  54.729980  163936.581742          14.053818
# 67                 9.250000  68.469676  320992.456376          28.294582
# 79                 6.353750  64.000391  262148.800838          20.452986
# 80                 8.506771  76.858109  454013.837540          16.963048
# ...                     ...        ...            ...                ...
# 23423              9.786458  47.579864  107713.362477           0.993916
# 23461              9.660417  48.218915  112112.054833           7.514910
# 23877              9.100833  49.041771  117950.133023           0.746003
# 23958              7.574107  43.430665   81919.906658           1.708735
# 25363             10.761806  73.139531  391251.952379           4.402487
#
#        GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 39                  0.61                0.00            0.00  ...
# 40                  2.58                7.27            7.27  ...
# 67                  5.76                1.26            1.26  ...
# 79                  0.97                0.03            0.03  ...
# 80                  6.14                2.50            2.50  ...
# ...                  ...                 ...             ...  ...
# 23423               0.00                0.00            0.00  ...
# 23461               0.00                0.00            0.00  ...
# 23877               0.00                0.00            0.00  ...
# 23958               0.00                0.00            0.00  ...
# 25363               5.57                0.22            0.22  ...
#
#        VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 39                       0.027878                 13.639532
# 40                       0.072745                  2.982541
# 67                       0.250179                  5.611151
# 79                       0.010288                  9.526749
# 80                       0.420633                  4.250609
# ...                           ...                       ...
# 23423                    0.348635                  0.232423
# 23461                    0.121556                  4.821718
# 23877                    0.980693                  2.666258
# 23958                    0.000000                  0.880734
# 25363                    0.000000                  4.830918
#
#        VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 39                   25.425146                   0.069696
# 40                   24.709020                   0.072745
# 67                   31.486776                   0.321658
# 79                   40.843621                   0.041152
# 80                   19.216294                   0.420633
# ...                        ...                        ...
# 23423                39.628123                   0.232423
# 23461                51.782820                   0.526742
# 23877                38.768005                   0.796813
# 23958                54.311927                   0.183486
# 25363                13.285024                   0.000000
#
#        VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 39                        0.000000                    0.006970
# 40                        0.048497                    0.181862
# 67                        0.035740                    0.071480
# 79                        0.020576                    0.000000
# 80                        0.066416                    0.088554
# ...                            ...                         ...
# 23423                     0.000000                    0.116212
# 23461                     0.000000                    0.121556
# 23877                     0.122587                    0.367760
# 23958                     0.000000                    0.073394
# 25363                     0.000000                    0.000000
#
#        VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 39                         0.006970               2.458422
# 40                         0.218235               2.364638
# 67                         0.178699               3.152242
# 79                         0.010288               2.276694
# 80                         0.221386               1.762301
# ...                             ...                    ...
# 23423                      0.058106               2.409639
# 23461                      0.283630               7.043011
# 23877                      0.337113               4.078437
# 23958                      0.293578               5.823910
# 25363                      0.000000               0.906871
#
#        VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 39                            28.331475     39.364371
# 40                            40.058196     16.585839
# 67                            31.665475     47.140815
# 79                            30.884774     50.154321
# 80                            22.647775     51.073721
# ...                                 ...           ...
# 23423                         44.973852     18.651947
# 23461                         27.350081     74.230146
# 23877                         34.293595     27.244867
# 23958                         39.559633     16.183486
# 25363                          7.004831     20.772947
#
# [495 rows x 38 columns]

# %%
#The defined bin
bins2= [10.0009, 20, 50, 101]
samples_per_bin2, binsP2 = np.histogram(df['DAM_perc_dmg'], bins=bins2)
plt.xlabel("Damage Values")
plt.ylabel("Frequency")
plt.plot(binsP2[1:],samples_per_bin2)

# %%
print(samples_per_bin2)
print(binsP2)
# Out:
# [214 191  90]
# [ 10.0009  20.      50.     101.    ]

# %%
#df['DAM_perc_dmg'].value_counts(bins=binsP2)

# %%
bin_index2=np.digitize(df['DAM_perc_dmg'], bins=binsP2)

# %%
y_input_strat=bin_index2

# %%
#the Beginning time to run the model 20 times
import datetime
now = datetime.datetime.now()
print ("Current date and time : ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current date and time :
# 2022-11-10 01:10:44

# %%
#Define empty lists for bins results(test)
test_RMSE_list_bin1=[]
test_RMSE_list_bin2=[]
test_RMSE_list_bin3=[]


#Define empty lists for bins results(train)
train_RMSE_list_bin1=[]
train_RMSE_list_bin2=[]
train_RMSE_list_bin3=[]

# %%
#Dropping highly correlated features (correlation value > 0.99) from X data.
features =[
    'HAZ_rainfall_Total', 
    'HAZ_rainfall_max_6h',
    'HAZ_rainfall_max_24h',
    'HAZ_v_max',
    'HAZ_v_max_3',
    'HAZ_dis_track_min',
    'GEN_landslide_per',
    'GEN_stormsurge_per',
    #'GEN_Bu_p_inSSA', 
    #'GEN_Bu_p_LS', 
    'GEN_Red_per_LSbldg',
    'GEN_Or_per_LSblg', 
    'GEN_Yel_per_LSSAb', 
    #'GEN_RED_per_SSAbldg',
    'GEN_OR_per_SSAbldg',
    'GEN_Yellow_per_LSbl',
    'TOP_mean_slope',
    'TOP_mean_elevation_m', 
    'TOP_ruggedness_stdev', 
    #'TOP_mean_ruggedness',
    #'TOP_slope_stdev', 
    'VUL_poverty_perc',
    'GEN_with_coast',
    'GEN_coast_length', 
    'VUL_Housing_Units',
    'VUL_StrongRoof_StrongWall', 
    'VUL_StrongRoof_LightWall',
    'VUL_StrongRoof_SalvageWall', 
    'VUL_LightRoof_StrongWall',
    'VUL_LightRoof_LightWall', 
    'VUL_LightRoof_SalvageWall',
    'VUL_SalvagedRoof_StrongWall',
    'VUL_SalvagedRoof_LightWall',
    'VUL_SalvagedRoof_SalvageWall', 
    'VUL_vulnerable_groups',
    'VUL_pantawid_pamilya_beneficiary']

# Split X and y from dataframe features
X = df[features]
display(X.columns)
y = df["DAM_perc_dmg"]

scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)

def func(x):
    return np.log(x+1)+1


for i in range(20): 
    X_train, X_test, y_train, y_test = train_test_split(X_scaled,df['DAM_perc_dmg'], stratify=y_input_strat, test_size=0.2)

    
    bin_index_test=np.digitize(y_test, bins=binsP2)
    bin_index_train=np.digitize(y_train, bins=binsP2)
    
    #Random Forest Reduced Overfitting
    rf = RandomForestRegressor(max_depth=None, n_estimators=100, min_samples_split=8,min_samples_leaf=5, max_samples=0.7)
    
    #Random Forest
    #rf = RandomForestRegressor(max_depth=None, n_estimators=100, min_samples_split=8,min_samples_leaf=5)
    
    rf_model=rf.fit(X_train, y_train, #sample_weight=y_train 
                    #sample_weight=np.log(y_train+1)+1    
                    #sample_weight=pow(y_train, 2)
                    )
    
    
    X2 = sm.add_constant(X_train)
    est = sm.OLS(y_train, X2)
    est2 = est.fit()
    print(est2.summary())
    
    y_pred_train = rf.predict(X_train)
    mse_train_idx1 = mean_squared_error(y_train[bin_index_train==1], y_pred_train[bin_index_train==1])
    rmse_train_1 = np.sqrt(mse_train_idx1)
    mse_train_idx2 = mean_squared_error(y_train[bin_index_train==2], y_pred_train[bin_index_train==2])
    rmse_train_2 = np.sqrt(mse_train_idx2)
    mse_train_idx3 = mean_squared_error(y_train[bin_index_train==3], y_pred_train[bin_index_train==3])
    rmse_train_3 = np.sqrt(mse_train_idx3)
    

    y_pred = rf.predict(X_test)
    mse_idx1 = mean_squared_error(y_test[bin_index_test==1], y_pred[bin_index_test==1])
    rmse_1 = np.sqrt(mse_idx1)
    mse_idx2 = mean_squared_error(y_test[bin_index_test==2], y_pred[bin_index_test==2])
    rmse_2 = np.sqrt(mse_idx2)
    mse_idx3 = mean_squared_error(y_test[bin_index_test==3], y_pred[bin_index_test==3])
    rmse_3 = np.sqrt(mse_idx3)

    
    
    print('----- Training_bins_RMSE  ------')
    print(f'Root mean squared error of bins_1: {rmse_train_1:.2f}')
    print(f'Root mean squared error of bins_2: {rmse_train_2:.2f}')
    print(f'Root mean squared error of bins_3: {rmse_train_3:.2f}')

    
    train_RMSE_list_bin1.append(rmse_train_1)
    train_RMSE_list_bin2.append(rmse_train_2)
    train_RMSE_list_bin3.append(rmse_train_3)
    
    
    print('----- Test_bins_RMSE  ------')
    print(f'Root mean squared error of bins_1: {rmse_1:.2f}')
    print(f'Root mean squared error of bins_2: {rmse_2:.2f}')
    print(f'Root mean squared error of bins_3: {rmse_3:.2f}')

    
    test_RMSE_list_bin1.append(rmse_1)
    test_RMSE_list_bin2.append(rmse_2)
    test_RMSE_list_bin3.append(rmse_3)
# Out:
# Index(['HAZ_rainfall_Total', 'HAZ_rainfall_max_6h', 'HAZ_rainfall_max_24h',
#        'HAZ_v_max', 'HAZ_v_max_3', 'HAZ_dis_track_min', 'GEN_landslide_per',
#        'GEN_stormsurge_per', 'GEN_Red_per_LSbldg', 'GEN_Or_per_LSblg',
#        'GEN_Yel_per_LSSAb', 'GEN_OR_per_SSAbldg', 'GEN_Yellow_per_LSbl',
#        'TOP_mean_slope', 'TOP_mean_elevation_m', 'TOP_ruggedness_stdev',
#        'VUL_poverty_perc', 'GEN_with_coast', 'GEN_coast_length',
#        'VUL_Housing_Units', 'VUL_StrongRoof_StrongWall',
#        'VUL_StrongRoof_LightWall', 'VUL_StrongRoof_SalvageWall',
#        'VUL_LightRoof_StrongWall', 'VUL_LightRoof_LightWall',
#        'VUL_LightRoof_SalvageWall', 'VUL_SalvagedRoof_StrongWall',
#        'VUL_SalvagedRoof_LightWall', 'VUL_SalvagedRoof_SalvageWall',
#        'VUL_vulnerable_groups', 'VUL_pantawid_pamilya_beneficiary'],
#       dtype='object')
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.463
# Model:                            OLS   Adj. R-squared:                  0.418
# Method:                 Least Squares   F-statistic:                     10.14
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           3.26e-33
# Time:                        01:11:52   Log-Likelihood:                -1663.4
# No. Observations:                 396   AIC:                             3391.
# Df Residuals:                     364   BIC:                             3518.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31
Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              138.885
# Skew:                           1.046   Prob(JB):                     6.94e-31
# Kurtosis:                       5.011   Cond. No.                     2.36e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.36e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 9.99
# Root mean squared error of bins_2: 7.92
# Root mean squared error of bins_3: 23.59
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 12.22
# Root mean squared error of bins_2: 10.69
# Root mean squared error of bins_3: 29.85
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     10.17
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           2.46e-33
# Time:                        01:11:53   Log-Likelihood:                -1652.4
# No. Observations:                 396   AIC:                             3369.
# Df Residuals:                     364   BIC:                             3496.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.1973      0.831     37.556      0.000      29.564      32.831
# x1            -7.6313      3.080     -2.477      0.014     -13.689      -1.574
# x2             5.7912      1.714      3.379      0.001       2.421       9.161
# x3             4.3861      3.728      1.176      0.240      -2.946      11.718
# x4           -10.2456      3.813     -2.687      0.008     -17.744      -2.747
# x5            18.2118      3.422      5.322      0.000      11.483      24.941
# x6            -1.3030      1.467     -0.888      0.375      -4.188       1.582
# x7          -644.9996    676.443     -0.954      0.341   -1975.227     685.228
# x8             1.1900      1.031      1.155      0.249      -0.837       3.217
# x9           197.4113    206.091      0.958      0.339    -207.867     602.689
# x10            1.9195      2.277      0.843      0.400      -2.558       6.397
# x11          556.3484    585.329      0.950      0.342    -594.703    1707.400
# x12            1.7840      0.977      1.826      0.069      -0.138       3.706
# x13           -1.3803      0.864     -1.597      0.111      -3.080       0.319
# x14           -0.9960      2.415     -0.412      0.680      -5.745       3.753
# x15           -0.1836      1.712     -0.107      0.915      -3.550       3.183
# x16           -0.0932      2.043     -0.046      0.964      -4.111       3.924
# x17           -7.0688      1.488     -4.751      0.000      -9.995      -4.143
# x18            2.7346      1.016      2.692      0.007       0.737       4.732
# x19           -1.2648      0.970     -1.304      0.193      -3.173       0.643
# x20           -2.4623      1.129     -2.180      0.030      -4.683      -0.241
# x21           12.4983     33.055      0.378      0.706     -52.505      77.501
# x22           17.2277     33.646      0.512      0.609     -48.938      83.393
# x23           -0.4180      2.068     -0.202      0.840      -4.484       3.648
# x24            3.8101      8.425      0.452      0.651     -12.757      20.378
# x25            9.3608     31.472      0.297      0.766     -52.529      71.250
# x26            1.1742      1.440      0.815      0.415      -1.658       4.007
# x27           -0.4760      0.890     -0.535      0.593      -2.227       1.275
# x28            2.5919      1.090      2.379      0.018       0.449       4.735
# x29            0.0362      1.550      0.023      0.981      -3.011       3.084
# x30            1.5785      1.228      1.286      0.199      -0.836       3.993
# x31           10.1267      1.176      8.614      0.000       7.815      12.438
# ==============================================================================
# Omnibus:                       88.384   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              189.414
# Skew:                           1.157   Prob(JB):                     7.40e-42
# Kurtosis:                       5.475   Cond. No.                     2.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 9.21
# Root mean squared error of bins_2: 7.71
# Root mean squared error of bins_3: 22.35
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 16.16
# Root mean squared error of bins_2: 10.33
# Root mean squared error of bins_3: 37.30
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     7.458
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           5.51e-24
# Time:                        01:11:53   Log-Likelihood:                -1675.2
# No. Observations:                 396   AIC:                             3414.
# Df Residuals:                     364   BIC:                             3542.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31
Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              159.184
# Skew:                           1.060   Prob(JB):                     2.71e-35
# Kurtosis:                       5.270   Cond. No.                     2.14e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 9.72
# Root mean squared error of bins_2: 8.10
# Root mean squared error of bins_3: 24.41
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 16.63
# Root mean squared error of bins_2: 8.89
# Root mean squared error of bins_3: 27.55
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.367
# Method:                 Least Squares   F-statistic:                     8.381
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           2.90e-27
# Time:                        01:11:55   Log-Likelihood:                -1672.5
# No. Observations:                 396   AIC:                             3409.
# Df Residuals:                     364   BIC:                             3536.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.0733      0.877     35.433      0.000      29.349      32.798
# x1            -6.6338      3.252     -2.040      0.042     -13.030      -0.238
# x2             4.0805      1.918      2.128      0.034       0.310       7.851
# x3             4.5773      4.113      1.113      0.266      -3.511      12.665
# x4            -6.2603      4.189     -1.495      0.136     -14.498       1.977
# x5            14.7779      3.675      4.021      0.000       7.551      22.005
# x6            -0.1285      1.600     -0.080      0.936      -3.274       3.018
# x7          -433.2824    688.773     -0.629      0.530   -1787.757     921.192
# x8             0.3631      1.054      0.344      0.731      -1.710       2.436
# x9           131.8531    209.816      0.628      0.530    -280.750     544.456
# x10            0.9706      2.345      0.414      0.679      -3.641       5.583
# x11          373.2861    595.995      0.626      0.531    -798.740    1545.312
# x12            1.9747      0.872      2.265      0.024       0.260       3.689
# x13           -0.5364      0.988     -0.543      0.588      -2.479       1.407
# x14           -3.3333      2.548     -1.308      0.192      -8.344       1.678
# x15            2.5009      1.707      1.465      0.144      -0.856       5.858
# x16            0.1735      2.092      0.083      0.934      -3.941       4.288
# x17           -5.6325      1.699     -3.315      0.001      -8.974      -2.291
# x18            2.2412      1.094      2.049      0.041       0.090       4.392
# x19           -1.4945      1.035     -1.443      0.150      -3.531       0.542
# x20           -3.0117      1.047     -2.878      0.004      -5.070      -0.954
# x21           12.5084     35.833      0.349      0.727     -57.958      82.974
# x22           16.8183     36.554      0.460      0.646     -55.066      88.702
# x23           -0.0277      2.167     -0.013      0.990      -4.288       4.233
# x24            4.4773      9.201      0.487      0.627     -13.616      22.571
# x25            8.7555     34.148      0.256      0.798     -58.397      75.908
# x26            0.9586      1.529      0.627      0.531      -2.049       3.966
# x27           -0.8717      0.944     -0.923      0.356      -2.728       0.985
# x28            2.6675      1.151      2.317      0.021       0.404       4.931
# x29            0.1580      1.553      0.102      0.919      -2.896       3.212
# x30            0.8283      1.328      0.624      0.533      -1.784       3.441
# x31           10.0965      1.413      7.144      0.000       7.317      12.876
# ==============================================================================
# Omnibus:                       75.216   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              149.050
# Skew:                           1.025   Prob(JB):                     4.31e-33
# Kurtosis:                       5.199   Cond. No.                     2.30e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 10.07
# Root mean squared error of bins_2: 7.63
# Root mean squared error of bins_3: 24.39
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 12.25
# Root mean squared error of bins_2: 11.77
# Root mean squared error of bins_3: 32.69
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.441
# Model:                            OLS   Adj. R-squared:                  0.394
# Method:                 Least Squares   F-statistic:                     9.270
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           2.53e-30
# Time:                        01:11:55   Log-Likelihood:                -1661.7
# No. Observations:                 396   AIC:                             3387.
# Df Residuals:                     364   BIC:                             3515.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         30.9408      0.848     36.479      0.000      29.273      32.609
# x1            -6.2934      3.134     -2.008      0.045     -12.457      -0.130
# x2             3.3343      1.752      1.904      0.058      -0.110       6.779
# x3             4.5880      3.741      1.226      0.221      -2.770      11.946
# x4            -7.1061      3.906     -1.819      0.070     -14.787       0.575
# x5            14.4352      3.492      4.134      0.000       7.568      21.302
# x6            -0.5299      1.530     -0.346      0.729      -3.539       2.480
# x7          -938.6008    664.719     -1.412      0.159   -2245.772     368.571
# x8             1.0040      1.108      0.906      0.366      -1.176       3.184
# x9           285.8866    202.480      1.412      0.159    -112.292     684.065
# x10            2.9233      2.284      1.280      0.201      -1.569       7.415
# x11          810.3978    575.223      1.409      0.160    -320.780    1941.576
# x12            1.8801      0.848      2.217      0.027       0.212       3.548
# x13           -0.9018      0.870     -1.036      0.301      -2.613       0.809
# x14           -2.9765      2.434     -1.223      0.222      -7.763       1.810
# x15            2.1790      1.661      1.312      0.190      -1.087       5.445
# x16            0.5672      2.047      0.277      0.782      -3.458       4.593
# x17           -4.6074      1.528     -3.016      0.003      -7.612      -1.603
# x18            2.3085      1.061      2.176      0.030       0.222       4.395
# x19           -1.3627      0.997     -1.366      0.173      -3.324       0.599
# x20           -3.0907      1.144     -2.702      0.007      -5.340      -0.842
# x21           -1.4277     33.701     -0.042      0.966     -67.702      64.846
# x22            1.8683     34.365      0.054      0.957     -65.710      69.447
# x23           -0.1362      2.230     -0.061      0.951      -4.522       4.250
# x24            1.0825      8.593      0.126      0.900     -15.816      17.981
# x25           -5.0019     32.099     -0.156      0.876     -68.125      58.122
# x26            1.3150      1.570      0.838      0.403      -1.773       4.403
# x27           -0.5650      0.920     -0.614      0.540      -2.375       1.245
# x28            1.2549      1.203      1.043      0.298      -1.111       3.621
# x29            0.2487      1.610      0.154      0.877      -2.918       3.416
# x30            0.6514      1.257      0.518      0.604      -1.820       3.123
# x31            9.9938      1.237      8.080      0.000       7.562      12.426
# ==============================================================================
# Omnibus:                       70.942   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.859
# Skew:                           0.985   Prob(JB):                     3.15e-30
# Kurtosis:                       5.086   Cond. No.                     2.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 9.93
# Root mean squared error of bins_2: 7.80
# Root mean squared error of bins_3: 22.45
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 12.65
# Root mean squared error of bins_2: 9.84
# Root mean squared error of bins_3: 37.73
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.404
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     7.956
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           9.11e-26
# Time:                        01:11:56   Log-Likelihood:                -1671.9
# No. Observations:                 396   AIC:                             3408.
# ...
# x19           -0.5414      0.970     -0.558      0.577      -2.449       1.366
# x20           -3.2338      1.020     -3.172      0.002      -5.239      -1.229
# x21           -0.4219     35.666     -0.012      0.991     -70.560      69.716
# x22            2.4062     36.377      0.066      0.947     -69.128      73.941
# x23           -1.3551      2.122     -0.639      0.524      -5.528       2.818
# x24            1.9905      9.076      0.219      0.827     -15.857      19.838
# x25           -3.9649     34.000     -0.117      0.907     -70.825      62.895
# x26            2.1102      1.447      1.458      0.146      -0.735       4.956
# x27           -0.9869      0.904     -1.092      0.275      -2.764       0.790
# x28            0.8376      1.244      0.673      0.501      -1.609       3.284
# x29            0.2394      1.501      0.160      0.873      -2.712       3.190
# x30            1.7150      1.183      1.450      0.148      -0.612       4.042
# x31           10.6858      1.416      7.549      0.000       7.902      13.469
# ==============================================================================
# Omnibus:                       57.840   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.744
# Skew:                           0.866   Prob(JB):                     3.61e-22
# Kurtosis:                       4.728   Cond. No.                     2.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 10.35
# Root mean squared error of bins_2: 7.86
# Root mean squared error of bins_3: 22.09
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 14.16
# Root mean squared error of bins_2: 8.21
# Root mean squared error of bins_3: 41.74
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.450
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     9.592
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           2.08e-31
# Time:                        01:11:58   Log-Likelihood:                -1659.5
# No. Observations:                 396   AIC:                             3383.
# Df Residuals:                     364   BIC:                             3510.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.0614      0.849     36.576      0.000      29.391      32.731
# x1            -8.3571      3.416     -2.446      0.015     -15.075      -1.639
# x2             5.2017      1.831      2.840      0.005       1.600       8.803
# x3             6.1668      4.158      1.483      0.139      -2.009      14.343
# x4            -8.0106      4.220     -1.898      0.058     -16.309       0.288
# x5            17.0694      3.712      4.599      0.000       9.770      24.369
# x6             0.0669      1.571      0.043      0.966      -3.022       3.156
# x7          -873.1129    638.736     -1.367      0.172   -2129.188     382.963
# x8             1.0060      0.949      1.060      0.290      -0.861       2.873
# x9           266.4170    194.592      1.369      0.172    -116.249     649.083
# x10            2.0986      2.180      0.962      0.336      -2.189       6.386
# x11          754.0862    552.749      1.364      0.173    -332.896    1841.069
# x12            1.1562      1.163      0.994      0.321      -1.131       3.443
# x13           -1.3657      0.875     -1.561      0.119      -3.086       0.355
# x14           -3.1221      2.508     -1.245      0.214      -8.055       1.811
# x15            1.5447      1.684      0.917      0.360      -1.766       4.856
# x16            0.6703      2.154      0.311      0.756      -3.565       4.906
# x17           -4.8154      1.539     -3.129      0.002      -7.842      -1.789
# x18            2.1027      1.063      1.978      0.049       0.012       4.193
# x19           -1.6019      1.010     -1.587      0.113      -3.587       0.383
# x20           -3.4380      1.046     -3.286      0.001      -5.495      -1.381
# x21           -2.2349     33.070     -0.068      0.946     -67.268      62.798
# x22            1.2232     33.730      0.036      0.971     -65.108      67.554
# x23           -2.2949      2.058     -1.115      0.265      -6.341       1.752
# x24           -0.0108      8.438     -0.001      0.999     -16.603      16.582
# x25           -4.7866     31.531     -0.152      0.879     -66.793      57.220
# x26           -0.4604      1.519     -0.303      0.762      -3.448       2.527
# x27           -0.5480      0.922     -0.595      0.553      -2.361       1.265
# x28            2.3627      1.152      2.050      0.041       0.097       4.629
# x29            0.4786      1.760      0.272      0.786      -2.982       3.940
# x30            0.0718      1.252      0.057      0.954      -2.391       2.534
# x31           10.0120      1.199      8.349      0.000       7.654      12.370
# ==============================================================================
# Omnibus:                       75.800   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              150.277
# Skew:                           1.032   Prob(JB):                     2.33e-33
# Kurtosis:                       5.202   Cond. No.                     2.19e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 9.23
# Root mean squared error of bins_2: 7.92
# Root mean squared error of bins_3: 22.30
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 14.18
# Root mean squared error of bins_2: 10.20
# Root mean squared error of bins_3: 37.18
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.399
# Model:                            OLS   Adj. R-squared:                  0.348
# Method:                 Least Squares   F-statistic:                     7.811
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           2.99e-25
# Time:                        01:11:58   Log-Likelihood:                -1677.4
# No. Observations:                 396   AIC:                             3419.
# Df Residuals:                     364   BIC:                             3546.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.7181      0.890     35.637      0.000      29.968      33.468
# x1            -8.3364      3.351     -2.488      0.013     -14.925      -1.748
# x2             2.2885      1.833      1.248      0.213      -1.317       5.894
# x3             7.9205      4.058      1.952      0.052      -0.059      15.900
# x4            -8.0585      3.991     -2.019      0.044     -15.906      -0.211
# x5            16.2964      3.634      4.484      0.000       9.149      23.443
# x6            -0.7037      1.615     -0.436      0.663      -3.880       2.473
# x7          -746.7468    657.481     -1.136      0.257   -2039.685     546.191
# x8             0.7253      1.188      0.611      0.542      -1.610       3.061
# x9           227.7336    200.246      1.137      0.256    -166.052     621.519
# x10            2.3946      2.318      1.033      0.302      -2.163       6.953
# x11          643.9477    568.962      1.132      0.258    -474.918    1762.813
# x12            1.8061      1.061      1.703      0.089      -0.280       3.892
# x13           -1.2673      0.896     -1.415      0.158      -3.028       0.494
# x14           -2.6696      2.611     -1.022      0.307      -7.805       2.466
# x15            2.2236      1.729      1.286      0.199      -1.176       5.624
# x16            0.0895      2.224      0.040      0.968      -4.284       4.463
# x17           -5.8354      1.619     -3.605      0.000      -9.018      -2.653
# x18            2.3200      1.157      2.006      0.046       0.045       4.595
# x19           -1.7033      1.095     -1.556      0.121      -3.856       0.449
# x20           -3.2252      1.169     -2.758      0.006      -5.525      -0.925
# x21           -5.6342     35.664     -0.158      0.875     -75.767      64.499
# x22           -1.0666     36.328     -0.029      0.977     -72.505      70.372
# x23           -2.1069      2.295     -0.918      0.359      -6.619       2.405
# x24            0.3127      9.088      0.034      0.973     -17.560      18.185
# x25           -7.9913     34.002     -0.235      0.814     -74.856      58.874
# x26           -0.2683      1.499     -0.179      0.858      -3.215       2.679
# x27            2.9900      2.044      1.463      0.144      -1.030       7.010
# x28            0.4497      1.305      0.345      0.731      -2.116       3.016
# x29            1.0483      1.793      0.585      0.559      -2.478       4.575
# x30            1.3926      1.355      1.028      0.305      -1.271       4.056
# x31           10.4216      1.293      8.059      0.000       7.879      12.965
# ==============================================================================
# Omnibus:                       93.193   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              198.776
# Skew:                           1.222   Prob(JB):                     6.86e-44
# Kurtosis:                       5.465   Cond. No.                     2.18e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 10.33
# Root mean squared error of bins_2: 7.51
# Root mean squared error of bins_3: 24.19
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 13.84
# Root mean squared error of bins_2: 11.04
# Root mean squared error of bins_3: 30.36
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.340
# Method:                 Least Squares   F-statistic:                     7.572
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           2.15e-24
# Time:                        01:11:59   Log-Likelihood:                -1671.8
# No. Observations:                 396   AIC:                             3408.
# Df Residuals:                     364   BIC:                             3535.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.6835      0.871     36.392      0.000      29.971      33.396
# x1            -9.4683      3.353     -2.824      0.005     -16.061      -2.875
# x2             4.2713      1.854      2.304      0.022       0.626       7.916
# x3             8.0496      4.047      1.989      0.047       0.091      16.008
# x4            -7.5606      3.844     -1.967      0.050     -15.119      -0.002
# x5            15.5022      3.452      4.491      0.000       8.715      22.290
# x6            -0.1621      1.542     -0.105      0.916      -3.194       2.870
# x7          -665.0737    713.171     -0.933      0.352   -2067.526     737.378
# x8             0.6207      1.092      0.569      0.570      -1.526       2.768
# x9           202.8196    217.251      0.934      0.351    -224.405     630.044
# x10            1.8165      2.401      0.757      0.450      -2.905       6.538
# x11          573.3681    617.216      0.929      0.354    -640.390    1787.126
# x12            2.0114      1.148      1.752      0.081      -0.246       4.269
# x13           -1.4489      0.885     -1.637      0.103      -3.190       0.292
# x14           -5.4660      2.501     -2.186      0.029     -10.384      -0.548
# x15            2.6600      1.791      1.485      0.138      -0.861       6.182
# x16            2.3089      2.153      1.072      0.284      -1.925       6.543
# x17           -6.4185      1.734     -3.702      0.000      -9.828      -3.009
# x18            2.2767      1.105      2.060      0.040       0.104       4.450
# x19           -1.5020      1.022     -1.470      0.142      -3.511       0.507
# x20           -2.7404      1.030     -2.661      0.008      -4.766      -0.715
# x21           -3.0508     32.846     -0.093      0.926     -67.642      61.540
# x22            1.6768     33.397      0.050      0.960     -63.998      67.352
# x23           -1.7572      2.123     -0.828      0.408      -5.933       2.419
# x24            1.3858      8.424      0.164      0.869     -15.181      17.952
# x25           -5.3078     31.240     -0.170      0.865     -66.741      56.126
# x26            0.2575      1.447      0.178      0.859      -2.589       3.104
# x27           -0.7096      0.935     -0.759      0.449      -2.549       1.130
# x28            2.2023      1.174      1.875      0.062      -0.107       4.512
# x29            0.3093      1.527      0.203      0.840      -2.694       3.312
# x30            1.9070      1.331      1.433      0.153      -0.710       4.524
# x31           10.6667      1.549      6.885      0.000       7.620      13.713
# ==============================================================================
# Omnibus:                       77.029   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              153.944
# Skew:                           1.044   Prob(JB):                     3.73e-34
# Kurtosis:                       5.230   Cond. No.                     2.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 9.98
# Root mean squared error of bins_2: 7.74
# Root mean squared error of bins_3: 23.97
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 15.66
# Root mean squared error of bins_2: 9.38
# Root mean squared error of bins_3: 34.75

# %%
#the End time of running the model 20 times
now = datetime.datetime.now()
print ("Current date and time : ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current date and time :
# 2022-11-10 01:11:59

# %%
#RMSE of bins_1

m_test_rmse = statistics.mean(test_RMSE_list_bin1)
plt.axvline(m_test_rmse, color='red', linestyle='dashed')
plt.hist(test_RMSE_list_bin1, bins=np.arange(9.0,19.0,0.5), edgecolor='k', histtype ='bar', density=True)
sd_test_rmse = statistics.stdev(test_RMSE_list_bin1)


m_train_rmse = statistics.mean(train_RMSE_list_bin1)
plt.axvline(m_train_rmse, color='b', linestyle='dashed')
plt.hist(train_RMSE_list_bin1, bins=np.arange(9.0,19.0,0.5), color='orange', edgecolor='k', histtype ='bar',
         density=True, alpha=0.7, #bins=np.arange(0.8,2.9,0.12)
        )
sd_train_rmse = statistics.stdev(train_RMSE_list_bin1)

print(f'stdev_RMSE_test: {sd_test_rmse:.2f}')
print(f'stdev_RMSE_train: {sd_train_rmse:.2f}')

print(f'mean_RMSE_test: {m_test_rmse:.2f}')
print(f'mean_RMSE_train: {m_train_rmse:.2f}')

#create legend
labels= ["Mean_test","Mean_train","test","train"]
plt.legend(labels)

plt.xlabel('The RMSE error')
plt.ylabel('Frequency')
plt.title('histogram of the RMSE distribution (bin1_(10.0, 20.0] )')
plt.show()
# Out:
# stdev_RMSE_test: 1.46
# stdev_RMSE_train: 0.33
# mean_RMSE_test: 14.40
# mean_RMSE_train: 9.88

# %%
#RMSE of bins_2

m_test_rmse = statistics.mean(test_RMSE_list_bin2)
plt.axvline(m_test_rmse, color='red', linestyle='dashed')
plt.hist(test_RMSE_list_bin2, bins=np.arange(6.5,16.5,0.5), edgecolor='k', histtype ='bar', density=True)
sd_test_rmse = statistics.stdev(test_RMSE_list_bin2)


m_train_rmse = statistics.mean(train_RMSE_list_bin2)
plt.axvline(m_train_rmse, color='b', linestyle='dashed')
plt.hist(train_RMSE_list_bin2, bins=np.arange(6.5,16.5,0.5), color='orange', edgecolor='k', histtype ='bar',
         density=True, alpha=0.7, #bins=np.arange(6.0,11.0,0.25)
        )
sd_train_rmse = statistics.stdev(train_RMSE_list_bin2)

print(f'stdev_RMSE_test: {sd_test_rmse:.2f}')
print(f'stdev_RMSE_train: {sd_train_rmse:.2f}')

print(f'mean_RMSE_test: {m_test_rmse:.2f}')
print(f'mean_RMSE_train: {m_train_rmse:.2f}')

#create legend
labels= ["Mean_test","Mean_train","test","train"]
plt.legend(labels)

plt.xlabel('The RMSE error')
plt.ylabel('Frequency')
plt.title('histogram of the RMSE distribution (bin2_(20.0, 50.0] )')
plt.show()
# Out:
# stdev_RMSE_test: 1.43
# stdev_RMSE_train: 0.19
# mean_RMSE_test: 10.67
# mean_RMSE_train: 7.70

# %%
#RMSE of bins_3

m_test_rmse = statistics.mean(test_RMSE_list_bin3)
plt.axvline(m_test_rmse, color='red', linestyle='dashed')
plt.hist(test_RMSE_list_bin3, bins=np.arange(14.0,36.0,1.2), edgecolor='k', histtype ='bar', density=True)
sd_test_rmse = statistics.stdev(test_RMSE_list_bin3)


m_train_rmse = statistics.mean(train_RMSE_list_bin3)
plt.axvline(m_train_rmse, color='b', linestyle='dashed')
plt.hist(train_RMSE_list_bin3, bins=np.arange(14.0,36.0,1.2), color='orange', edgecolor='k', histtype ='bar',
         density=True, alpha=0.7)
sd_train_rmse = statistics.stdev(train_RMSE_list_bin3)

print(f'stdev_RMSE_test: {sd_test_rmse:.2f}')
print(f'stdev_RMSE_train: {sd_train_rmse:.2f}')

print(f'mean_RMSE_test: {m_test_rmse:.2f}')
print(f'mean_RMSE_train: {m_train_rmse:.2f}')

#create legend
labels= ["Mean_test","Mean_train","test","train"]
plt.legend(labels)

plt.xlabel('The RMSE error')
plt.ylabel('Frequency')
plt.title('histogram of the RMSE distribution (bin3_(50.0, 100.0] )')
plt.show()
# Out:
# stdev_RMSE_test: 3.97
# stdev_RMSE_train: 0.86
# mean_RMSE_test: 32.67
# mean_RMSE_train: 23.57
