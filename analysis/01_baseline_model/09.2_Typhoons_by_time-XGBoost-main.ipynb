# %% [markdown]
# Implementing XGBoost Regression model on the input data
#
# Estimate and plot the Root Mean Square Error of 8 different test sets.
#
# The idea is to do a train-test-split based on the typhoon's time. Therefore, typhoons are ordered with respect to their time of occurrence and then the 8 recent typhoons are selected as the test set (8 as a test over 39 typhoons in total means 20% as a test while 80% as a train). Then 8 different RMSEs are estimated while for each calculation one of the less recent typhoons was dropped from the test set and added to the train set. The idea is to determine how well the model performs in learning from older typhoons' characteristics to make predictions on the target value of the most recent ones.

# %%
# %load_ext jupyter_black

# %%
import statistics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, max_error

from utils import get_clean_dataset

# %%
df = get_clean_dataset()

# %%
#Define bins
#bins2= [0, 1, 60, 101]   #Old bins
bins2 = [0, 0.00009, 1, 10, 50, 101]    #New bins
samples_per_bin2, binsP2 = np.histogram(df['DAM_perc_dmg'], bins=bins2)
plt.xlabel("Damage Values")
plt.ylabel("Frequency")
plt.plot(binsP2[1:],samples_per_bin2)

print(samples_per_bin2)
print(binsP2)
# Out:
# [4086 2431 1061  405   90]
# [0.00e+00 9.00e-05 1.00e+00 1.00e+01 5.00e+01 1.01e+02]

# %% [markdown]
# ###The data (except target) needs to be standardize

# %%
#Separate target from all other data
#df_scaled = df
#df_scaled

#Separate typhoon from other features
dfs = np.split(df, [1], axis=1)
dfa = np.split(dfs[1], [36], axis=1)
#print(dfs[0], dfs[1], dfa[0], dfa[1])

#Standardaize data 
scaler = preprocessing.StandardScaler().fit(dfa[0])
X1 = scaler.transform(dfa[0])
Xnew = pd.DataFrame(X1)
display(Xnew)
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.429453  0.901680  0.766418  1.592258  1.332271 -1.443648  0.781691
# 1    -1.002249 -1.004823 -1.004232 -0.896964 -0.543458  1.423220 -0.597476
# 2    -0.878043 -0.743714 -0.829731 -0.777769 -0.536155  1.288795  0.182983
# 3    -0.952819 -0.845094 -0.922008 -0.715243 -0.530911  1.066918 -0.629550
# 4    -0.963981 -0.924749 -0.936450 -0.793073 -0.537281  1.120728  2.321226
# ...        ...       ...       ...       ...       ...       ...       ...
# 8068 -0.995121 -1.011089 -1.013966 -0.928759 -0.544885  1.310395  0.332660
# 8069 -0.931325 -0.876566 -0.971649 -0.838334 -0.540275  1.598024 -0.629550
# 8070 -0.980663 -0.983516 -1.010444 -0.517240 -0.506472  0.640566 -0.597476
# 8071 -0.979753 -0.878516 -0.965113 -0.620712 -0.520841  0.719548 -0.629550
# 8072 -0.812281 -0.832468 -0.766925 -0.524996 -0.507681  0.733116  1.588878
#
#             7         8         9   ...        26        27        28  \
# 0     0.473193  0.474260  0.782109  ... -0.932648 -0.388957  0.337830
# 1    -0.351584 -0.351508 -0.597673  ...  0.691991  1.116440 -0.106247
# 2    -0.180756 -0.180475  0.183134  ...  0.009907 -0.189419 -0.292472
# 3    -0.351584 -0.351508 -0.629761  ... -0.423542 -0.025027 -0.289853
# 4    -0.303539 -0.303405  2.322332  ...  0.620671 -0.452411 -0.240474
# ...        ...       ...       ...  ...       ...       ...       ...
# 8068  0.482535  0.483613  0.332878  ... -0.207321 -0.209948  0.702918
# 8069 -0.351584 -0.351508 -0.629761  ... -0.597539 -0.165655 -0.388452
# 8070 -0.339573 -0.339482 -0.597673  ... -0.029475 -0.178278 -0.487495
# 8071 -0.351584 -0.351508 -0.629761  ...  0.432899 -0.583838 -0.486006
# 8072  0.055466  0.056031  1.589656  ... -1.224474 -0.521536  3.603347
#
#             29        30        31        32        33        34        35
# 0     2.004665  3.945376 -0.321955 -0.275767 -0.231135  0.495246  1.947946
# 1     0.038993  1.914435  0.023188 -0.049568 -0.143622  0.763418  0.238529
# 2     0.174483 -0.207586 -0.321955 -0.321666 -0.254022 -0.072272  0.744326
# 3    -0.416442 -0.443236 -0.188433 -0.376621 -0.098239 -0.447767  0.534280
# 4     1.201765 -0.547616 -0.321955 -0.257594 -0.480336 -0.587862  0.978342
# ...        ...       ...       ...       ...       ...       ...       ...
# 8068  1.350502  0.849154  0.035392  0.187740 -0.387371  0.409624  0.672720
# 8069 -0.583216 -0.422637 -0.321955 -0.250377 -0.189196 -0.805064 -0.840787
# 8070 -0.697345 -0.446611 -0.321955 -0.131755 -0.413109 -0.758790 -1.119753
# 8071 -0.693494 -0.547616 -0.321955 -0.376621 -0.480336  0.416342 -0.092956
# 8072  1.607950  0.709216 -0.202864 -0.263772 -0.170517  0.195202  0.699308
#
# [8073 rows x 36 columns]

# %%
dfa[1] = dfa[1].astype(float)

# %%
Xnew = pd.concat([Xnew.reset_index(drop=True), dfa[1].reset_index(drop=True)], axis=1)
Xnew
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.429453  0.901680  0.766418  1.592258  1.332271 -1.443648  0.781691
# 1    -1.002249 -1.004823 -1.004232 -0.896964 -0.543458  1.423220 -0.597476
# 2    -0.878043 -0.743714 -0.829731 -0.777769 -0.536155  1.288795  0.182983
# 3    -0.952819 -0.845094 -0.922008 -0.715243 -0.530911  1.066918 -0.629550
# 4    -0.963981 -0.924749 -0.936450 -0.793073 -0.537281  1.120728  2.321226
# ...        ...       ...       ...       ...       ...       ...       ...
# 8068 -0.995121 -1.011089 -1.013966 -0.928759 -0.544885  1.310395  0.332660
# 8069 -0.931325 -0.876566 -0.971649 -0.838334 -0.540275  1.598024 -0.629550
# 8070 -0.980663 -0.983516 -1.010444 -0.517240 -0.506472  0.640566 -0.597476
# 8071 -0.979753 -0.878516 -0.965113 -0.620712 -0.520841  0.719548 -0.629550
# 8072 -0.812281 -0.832468 -0.766925 -0.524996 -0.507681  0.733116  1.588878
#
#              7         8         9  ...        27        28        29  \
# 0     0.473193  0.474260  0.782109  ... -0.388957  0.337830  2.004665
# 1    -0.351584 -0.351508 -0.597673  ...  1.116440 -0.106247  0.038993
# 2    -0.180756 -0.180475  0.183134  ... -0.189419 -0.292472  0.174483
# 3    -0.351584 -0.351508 -0.629761  ... -0.025027 -0.289853 -0.416442
# 4    -0.303539 -0.303405  2.322332  ... -0.452411 -0.240474  1.201765
# ...        ...       ...       ...  ...       ...       ...       ...
# 8068  0.482535  0.483613  0.332878  ... -0.209948  0.702918  1.350502
# 8069 -0.351584 -0.351508 -0.629761  ... -0.165655 -0.388452 -0.583216
# 8070 -0.339573 -0.339482 -0.597673  ... -0.178278 -0.487495 -0.697345
# 8071 -0.351584 -0.351508 -0.629761  ... -0.583838 -0.486006 -0.693494
# 8072  0.055466  0.056031  1.589656  ... -0.521536  3.603347  1.607950
#
#             30        31        32        33        34        35  DAM_perc_dmg
# 0     3.945376 -0.321955 -0.275767 -0.231135  0.495246  1.947946      3.632568
# 1     1.914435  0.023188 -0.049568 -0.143622  0.763418  0.238529      0.000000
# 2    -0.207586 -0.321955 -0.321666 -0.254022 -0.072272  0.744326      0.000000
# 3    -0.443236 -0.188433 -0.376621 -0.098239 -0.447767  0.534280      0.000000
# 4    -0.547616 -0.321955 -0.257594 -0.480336 -0.587862  0.978342      0.000000
# ...        ...       ...       ...       ...       ...       ...           ...
# 8068  0.849154  0.035392  0.187740 -0.387371  0.409624  0.672720      0.000000
# 8069 -0.422637 -0.321955 -0.250377 -0.189196 -0.805064 -0.840787      0.000000
# 8070 -0.446611 -0.321955 -0.131755 -0.413109 -0.758790 -1.119753      0.000000
# 8071 -0.547616 -0.321955 -0.376621 -0.480336  0.416342 -0.092956      0.000000
# 8072  0.709216 -0.202864 -0.263772 -0.170517  0.195202  0.699308      0.000000
#
# [8073 rows x 37 columns]

# %%
i=0
for feature in features:
    Xnew = Xnew.rename(columns={i: feature})
    i+=1
    
Xnew = pd.concat([dfs[0].reset_index(drop=True),Xnew.reset_index(drop=True)], axis=1)
#Xnew

# %%
typhoons_lst = Xnew.typhoon.unique()
tls=typhoons_lst.tolist()

# %%
df_typhoon=pd.DataFrame(columns = ['typhoon', 'year'])

for i in range(len(tls)):
    df_typhoon.at[i,'typhoon']=tls[i]
    df_typhoon.at[i,'year'] = int(tls[i][-4:])
    
df_typhoon_sort = df_typhoon.sort_values('year')
df_typhoon_sort=df_typhoon_sort.reset_index(drop=True)
df_typhoon_sort
# Out:
#           typhoon  year
# 0      durian2006  2006
# 1    fengshen2008  2008
# 2     ketsana2009  2009
# 3      conson2010  2010
# 4       nesat2011  2011
# 5       bopha2012  2012
# 6        nari2013  2013
# 7       krosa2013  2013
# 8      haiyan2013  2013
# 9       usagi2013  2013
# 10       utor2013  2013
# 11     jangmi2014  2014
# 12   kalmaegi2014  2014
# 13   rammasun2014  2014
# 14    hagupit2014  2014
# 15  fung-wong2014  2014
# 16   lingling2014  2014
# 17    mujigae2015  2015
# 18      melor2015  2015
# 19       noul2015  2015
# 20       goni2015  2015
# 21      linfa2015  2015
# 22      koppu2015  2015
# 23   mekkhala2015  2015
# 24      haima2016  2016
# 25     tokage2016  2016
# 26    meranti2016  2016
# 27   nock-ten2016  2016
# 28     sarika2016  2016
# 29   mangkhut2018  2018
# 30       yutu2018  2018
# 31    kammuri2019  2019
# 32      nakri2019  2019
# 33   phanfone2019  2019
# 34     saudel2020  2020
# 35       goni2020  2020
# 36      vamco2020  2020
# 37   vongfong2020  2020
# 38     molave2020  2020

# %%
#Define an empty list to append the estimated rmse to the list
rmse_test_list=[]

#Define an empty list to append the selected typhoons to the list
test_list = []

#Define 5 empty lists to append the estimated rmse for each bin to the each list
rmse_list_1=[]
rmse_list_2=[]
rmse_list_3=[]
rmse_list_4=[]
rmse_list_5=[]

# %% [markdown]
# ####Check the mean value of each group of typhoon to figure out most severe typhoons.

# %%
i_list=[38, 37, 36, 35, 34, 33, 32, 31]
for i in range(len(i_list)):
    test_list.append(df_typhoon_sort.iloc[i_list[i], 0])

print(test_list)
# Out:
# ['molave2020', 'vongfong2020', 'vamco2020', 'goni2020', 'saudel2020', 'phanfone2019', 'nakri2019', 'kammuri2019']

# %%
#Reorder test_list according to typhoons'dates from months in 2019 to last one in November 2020 

test_list=['nakri2019', 'kammuri2019', 'phanfone2019', 'vongfong2020', 'saudel2020', 'molave2020', 'goni2020', 'vamco2020']

# %%
ltl=len(test_list)
ltl
# Out:
# 8

# %%
#df_test=pd.DataFrame(Xnew, columns = ['typhoon','HAZ_rainfall_Total',
df_test=pd.DataFrame(columns = ['typhoon','HAZ_rainfall_Total',
                                      'HAZ_rainfall_max_6h',
                                      'HAZ_rainfall_max_24h',
                                      'HAZ_v_max',
                                      'HAZ_v_max_3',
                                      'HAZ_dis_track_min',
                                      'GEN_landslide_per',
                                      'GEN_stormsurge_per',
                                      'GEN_Bu_p_inSSA', 
                                      'GEN_Bu_p_LS', 
                                      'GEN_Red_per_LSbldg',
                                      'GEN_Or_per_LSblg', 
                                      'GEN_Yel_per_LSSAb', 
                                      'GEN_RED_per_SSAbldg',
                                      'GEN_OR_per_SSAbldg',
                                      'GEN_Yellow_per_LSbl',
                                      'TOP_mean_slope',
                                      'TOP_mean_elevation_m', 
                                      'TOP_ruggedness_stdev', 
                                      'TOP_mean_ruggedness',
                                      'TOP_slope_stdev', 
                                      'VUL_poverty_perc',
                                      'GEN_with_coast',
                                      'GEN_coast_length', 
                                      'VUL_Housing_Units',
                                      'VUL_StrongRoof_StrongWall', 
                                      'VUL_StrongRoof_LightWall',
                                      'VUL_StrongRoof_SalvageWall', 
                                      'VUL_LightRoof_StrongWall',
                                      'VUL_LightRoof_LightWall', 
                                      'VUL_LightRoof_SalvageWall',
                                      'VUL_SalvagedRoof_StrongWall',
                                      'VUL_SalvagedRoof_LightWall',
                                      'VUL_SalvagedRoof_SalvageWall', 
                                      'VUL_vulnerable_groups',
                                      'VUL_pantawid_pamilya_beneficiary', 
                                      'DAM_perc_dmg']) 
#df_test

# %% [markdown]
# In the following cell the RMSE is calculated for different test set and added to a list for plotting.

# %%
while ltl!=0:

    if ltl==8:   
        df_test = Xnew[Xnew['typhoon'] == test_list[7]]
        df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[6]])
        df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[5]])
        df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[4]])
        df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[3]])
        df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[2]])
        df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[1]])
        df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[0]])

        Xnew.drop(Xnew.index[Xnew['typhoon'] == test_list[7]], inplace=True)
        Xnew.drop(Xnew.index[Xnew['typhoon'] == test_list[6]], inplace=True)
        Xnew.drop(Xnew.index[Xnew['typhoon'] == test_list[5]], inplace=True)
        Xnew.drop(Xnew.index[Xnew['typhoon'] == test_list[4]], inplace=True)
        Xnew.drop(Xnew.index[Xnew['typhoon'] == test_list[3]], inplace=True)
        Xnew.drop(Xnew.index[Xnew['typhoon'] == test_list[2]], inplace=True)
        Xnew.drop(Xnew.index[Xnew['typhoon'] == test_list[1]], inplace=True)
        Xnew.drop(Xnew.index[Xnew['typhoon'] == test_list[0]], inplace=True)   

        display(df_test)    
        df_train=Xnew
        display(df_train)


    elif ltl < 8:

            if ltl==7:
                num=0

            elif ltl==6:
                num=1

            elif ltl==5:
                num=2

            elif ltl==4:
                num=3

            elif ltl==3:
                num=4

            elif ltl==2:
                num=5

            elif ltl==1:
                num=6

            df_train=df_train.append(df_test[df_test['typhoon'] == test_list[num]])
            df_test.drop(df_test.index[df_test['typhoon'] == test_list[num]], inplace=True)



            display(df_test)
            display(df_train)


    # Split X and y from dataframe features
    X_test = df_test[features]
    X_train = df_train[features]

    y_train = df_train["DAM_perc_dmg"]
    y_test = df_test["DAM_perc_dmg"]

    bin_index_test=np.digitize(y_test, bins=binsP2)
    bin_index_train=np.digitize(y_train, bins=binsP2)


    #XGBoost

    xgb = XGBRegressor(n_estimators=100, max_depth=4, learning_rate=0.1, gamma=1, reg_lambda=0.1, colsample_bytree=0.8)
    xgb_model=xgb.fit(X_train, y_train)

    #XGBoost_ReducedOverfitting
    #xgb = XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=0.8,
    #                   colsample_bynode=0.8, colsample_bytree=0.8, gamma=3, eta=0.01,
    #                   importance_type='gain', learning_rate=0.1, max_delta_step=0,
    #                   max_depth=4, min_child_weight=1, missing=1, n_estimators=100, early_stopping_rounds=10,
    #                   n_jobs=1, nthread=None, objective='reg:squarederror', 
    #                   reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
    #                   silent=None, subsample=0.8, verbosity=1, eval_metric=["rmse", "logloss"],
    #                   #random_state=0,
    #                  )


    #eval_set = [(X_test, y_test)]
    #xgb_model=xgb.fit(X_train, y_train, eval_set=eval_set, verbose=False)



    #RMSE Estimation for each bins
    y_pred_train = xgb.predict(X_train)

    mse_train_idx1 = mean_squared_error(y_train[bin_index_train==1], y_pred_train[bin_index_train==1])
    rmse_train_1 = np.sqrt(mse_train_idx1)
    mse_train_idx2 = mean_squared_error(y_train[bin_index_train==2], y_pred_train[bin_index_train==2])
    rmse_train_2 = np.sqrt(mse_train_idx2)
    mse_train_idx3 = mean_squared_error(y_train[bin_index_train==3], y_pred_train[bin_index_train==3])
    rmse_train_3 = np.sqrt(mse_train_idx3)
    mse_train_idx4 = mean_squared_error(y_train[bin_index_train==4], y_pred_train[bin_index_train==4])
    rmse_train_4 = np.sqrt(mse_train_idx4)
    mse_train_idx5 = mean_squared_error(y_train[bin_index_train==5], y_pred_train[bin_index_train==5])
    rmse_train_5 = np.sqrt(mse_train_idx5)


    print('----- Training_bins_RMSE  ------')
    print(f'Root mean squared error of bins_1: {rmse_train_1:.2f}')
    print(f'Root mean squared error of bins_2: {rmse_train_2:.2f}')
    print(f'Root mean squared error of bins_3: {rmse_train_3:.2f}')
    print(f'Root mean squared error of bins_4: {rmse_train_4:.2f}')
    print(f'Root mean squared error of bins_5: {rmse_train_5:.2f}')


    y_pred = xgb.predict(X_test)

    mse_idx1 = mean_squared_error(y_test[bin_index_test==1], y_pred[bin_index_test==1])
    rmse_1 = np.sqrt(mse_idx1)

    if len(y_test[bin_index_test==2])==0:
        rmse_2=-1
    else:
        mse_idx2 = mean_squared_error(y_test[bin_index_test==2], y_pred[bin_index_test==2])
        rmse_2 = np.sqrt(mse_idx2)

    if len(y_test[bin_index_test==3])==0:
        rmse_3=-1
    else:
        mse_idx3 = mean_squared_error(y_test[bin_index_test==3], y_pred[bin_index_test==3])
        rmse_3 = np.sqrt(mse_idx3)

    if len(y_test[bin_index_test==4])==0:
        rmse_4=-1
    else:
        mse_idx4 = mean_squared_error(y_test[bin_index_test==4], y_pred[bin_index_test==4])
        rmse_4 = np.sqrt(mse_idx4)

    if len(y_test[bin_index_test==5])==0:
        rmse_5=-1
    else:
        mse_idx5 = mean_squared_error(y_test[bin_index_test==5], y_pred[bin_index_test==5])
        rmse_5 = np.sqrt(mse_idx5)


    print('----- Test_bins_RMSE  ------')
    print(f'Root mean squared error of bins_1: {rmse_1:.2f}')
    print(f'Root mean squared error of bins_2: {rmse_2:.2f}')
    print(f'Root mean squared error of bins_3: {rmse_3:.2f}')
    print(f'Root mean squared error of bins_4: {rmse_4:.2f}')
    print(f'Root mean squared error of bins_5: {rmse_5:.2f}')

    rmse_list_1.append(rmse_1)
    rmse_list_2.append(rmse_2)
    rmse_list_3.append(rmse_3)
    rmse_list_4.append(rmse_4)
    rmse_list_5.append(rmse_5)


    #Different Error Estimation
    y_pred_train = xgb.predict(X_train)
    mae_train = mean_absolute_error(y_train, y_pred_train)
    mse_train = mean_squared_error(y_train, y_pred_train)
    rmse_train = np.sqrt(mse_train)
    mx_train = max_error(y_train, y_pred_train)
    me_train = (y_pred_train - y_train).sum()/len(y_train)

    y_pred = xgb.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mx = max_error(y_test, y_pred)
    me = (y_pred - y_test).sum()/len(y_test)

    print('----- Test  ------')
    print(f'Mean absolute error: {mae:.2f}')
    print(f'Mean squared error: {mse:.2f}')
    print(f'Root mean squared error: {rmse:.2f}')
    print(f'Max error: {mx:.2f}')
    print(f"Average Error: {me:.2f}")

    print('---- Training -----')
    print(f'Mean absolute error: {mae_train:.2f}')
    print(f'Mean squared error: {mse_train:.2f}')
    print(f'Root mean squared error: {rmse_train:.2f}')
    print(f'Max error: {mx_train:.2f}')
    print(f"Average Error: {me_train:.2f}")


    score = xgb.score(X_train, y_train)  
    print("Training score coefficient of determination for the model R^2: %.3f " % (score))

    rmse_test_list.append(rmse)

    #ltl means len(test_list)
    ltl=ltl-1
    ltl



rmse_test_list
# Out:
# /tmp/ipykernel_92233/3041326752.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[6]])
# /tmp/ipykernel_92233/3041326752.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[5]])
# /tmp/ipykernel_92233/3041326752.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[4]])
# /tmp/ipykernel_92233/3041326752.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[3]])
# /tmp/ipykernel_92233/3041326752.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[2]])
# /tmp/ipykernel_92233/3041326752.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[1]])
# /tmp/ipykernel_92233/3041326752.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test=df_test.append(Xnew[Xnew['typhoon'] == test_list[0]])
#           typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 6800    vamco2020            0.271298             0.341942
# 6801    vamco2020            1.704740             0.525577
# 6802    vamco2020            0.701594             0.235326
# 6803    vamco2020            1.973405             0.990513
# 6804    vamco2020           -0.177600            -0.468540
# ...           ...                 ...                  ...
# 3300  kammuri2019            0.251819             0.368370
# 3301  kammuri2019            0.321951             1.024028
# 3302  kammuri2019           -0.870427            -0.841752
# 5268    nakri2019           -0.773676            -0.913927
# 5269    nakri2019           -0.827266            -0.903877
#
#       HAZ_rainfall_max_24h  HAZ_v_max  HAZ_v_max_3  HAZ_dis_track_min  \
# 6800              0.347412  -0.165874    -0.425196          -1.030969
# 6801              1.356928  -0.400363    -0.485447          -0.463913
# 6802              0.104512  -1.056908    -0.548821           0.533616
# 6803              1.697358  -0.304684    -0.463980          -0.708142
# 6804             -0.269478  -0.429711    -0.491240          -0.688008
# ...                    ...        ...          ...                ...
# 3300              0.340007   0.072635    -0.334333          -0.223672
# 3301              0.613993   1.551381     1.255283          -0.758349
# 3302             -0.846123  -0.561017    -0.513008           1.025970
# 5268             -0.845051  -0.714947    -0.530884           1.496320
# 5269             -0.856201  -0.717084    -0.531081           1.519221
#
#       GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 6800          -0.212592            5.102888        5.100166  ...
# 6801           1.257450            0.018098        0.018618  ...
# 6802          -0.629550           -0.351584       -0.351508  ...
# 6803           1.391090            1.694343        1.692870  ...
# 6804          -0.629550           -0.351584       -0.351508  ...
# ...                 ...                 ...             ...  ...
# 3300           1.588878            0.055466        0.056031  ...
# 3301          -0.068261            1.095112        1.091582  ...
# 3302          -0.629550           -0.351584       -0.351508  ...
# 5268          -0.544020           -0.340907       -0.340819  ...
# 5269           1.984453           -0.055305       -0.054873  ...
#
#       VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 6800                   -0.346117                 -0.433989
# 6801                    0.810547                  0.081525
# 6802                   -0.583838                 -0.481673
# 6803                   -0.357750                 -0.021535
# 6804                    0.132192                 -0.440675
# ...                          ...                       ...
# 3300                   -0.521536                  3.603347
# 3301                   -0.089043                  0.507463
# 3302                   -0.070763                 -0.402397
# 5268                   -0.226072                  0.079594
# 5269                   -0.499303                 -0.346608
#
#       VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 6800                -0.758678                  -0.547616
# 6801                 0.138999                   1.441321
# 6802                -0.493736                  -0.547616
# 6803                 0.320360                  -0.547616
# 6804                -0.601943                  -0.280123
# ...                       ...                        ...
# 3300                 1.607950                   0.709216
# 3301                 0.065949                   0.621402
# 3302                -0.135896                  -0.317607
# 5268                 2.640732                   0.165203
# 5269                 1.732524                  -0.310763
#
#       VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 6800                    -0.321955                   -0.337477
# 6801                    -0.321955                   -0.376621
# 6802                    -0.321955                   -0.298837
# 6803                    -0.321955                   -0.274242
# 6804                    -0.321955                   -0.088408
# ...                           ...                         ...
# 3300                    -0.202864                   -0.263772
# 3301                    -0.091894                    0.035161
# 3302                    -0.125805                   -0.314665
# 5268                    -0.321955                    0.055398
# 5269                    -0.321955                   -0.300061
#
#       VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 6800                     -0.448095              -0.947447
# 6801                     -0.196669              -0.195917
# 6802                     -0.480336              -0.542169
# 6803                     -0.396013              -0.378751
# 6804                     -0.331972              -0.404409
# ...                            ...                    ...
# 3300                     -0.170517               0.195202
# 3301                     -0.220981              -0.766019
# 3302                     -0.429307               0.541929
# 5268                     -0.124512              -0.627993
# 5269                     -0.480336              -0.013931
#
#       VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 6800                         -1.150918      0.000000
# 6801                         -0.346559      0.000000
# 6802                          0.460075      0.000000
# 6803                         -0.166851      0.056513
# 6804                         -0.692202      0.000000
# ...                                ...           ...
# 3300                          0.699308      1.038206
# 3301                         -0.329254     24.047333
# 3302                         -0.579196      0.000000
# 5268                          0.814757      0.000000
# 5269                          0.935459      0.000000
#
# [1526 rows x 38 columns]
#          typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 0     durian2006            0.429453             0.901680
# 1     durian2006           -1.002249            -1.004823
# 2     durian2006           -0.878043            -0.743714
# 3     durian2006           -0.952819            -0.845094
# 4     durian2006           -0.963981            -0.924749
# ...          ...                 ...                  ...
# 8068    noul2015           -0.995121            -1.011089
# 8069    noul2015           -0.931325            -0.876566
# 8070    noul2015           -0.980663            -0.983516
# 8071    noul2015           -0.979753            -0.878516
# 8072    noul2015           -0.812281            -0.832468
#
#       HAZ_rainfall_max_24h  HAZ_v_max  HAZ_v_max_3  HAZ_dis_track_min  \
# 0                 0.766418   1.592258     1.332271          -1.443648
# 1                -1.004232  -0.896964    -0.543458           1.423220
# 2                -0.829731  -0.777769    -0.536155           1.288795
# 3                -0.922008  -0.715243    -0.530911           1.066918
# 4                -0.936450  -0.793073    -0.537281           1.120728
# ...                    ...        ...          ...                ...
# 8068             -1.013966  -0.928759    -0.544885           1.310395
# 8069             -0.971649  -0.838334    -0.540275           1.598024
# 8070             -1.010444  -0.517240    -0.506472           0.640566
# 8071             -0.965113  -0.620712    -0.520841           0.719548
# 8072             -0.766925  -0.524996    -0.507681           0.733116
#
#       GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 0              0.781691            0.473193        0.474260  ...
# 1             -0.597476           -0.351584       -0.351508  ...
# 2              0.182983           -0.180756       -0.180475  ...
# 3             -0.629550           -0.351584       -0.351508  ...
# 4              2.321226           -0.303539       -0.303405  ...
# ...                 ...                 ...             ...  ...
# 8068           0.332660            0.482535        0.483613  ...
# 8069          -0.629550           -0.351584       -0.351508  ...
# 8070          -0.597476           -0.339573       -0.339482  ...
# 8071          -0.629550           -0.351584       -0.351508  ...
# 8072           1.588878            0.055466        0.056031  ...
#
#       VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 0                      -0.388957                  0.337830
# 1                       1.116440                 -0.106247
# 2                      -0.189419                 -0.292472
# 3                      -0.025027                 -0.289853
# 4                      -0.452411                 -0.240474
# ...                          ...                       ...
# 8068                   -0.209948                  0.702918
# 8069                   -0.165655                 -0.388452
# 8070                   -0.178278                 -0.487495
# 8071                   -0.583838                 -0.486006
# 8072                   -0.521536                  3.603347
#
#       VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 0                    2.004665                   3.945376
# 1                    0.038993                   1.914435
# 2                    0.174483                  -0.207586
# 3                   -0.416442                  -0.443236
# 4                    1.201765                  -0.547616
# ...                       ...                        ...
# 8068                 1.350502                   0.849154
# 8069                -0.583216                  -0.422637
# 8070                -0.697345                  -0.446611
# 8071                -0.693494                  -0.547616
# 8072                 1.607950                   0.709216
#
#       VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 0                       -0.321955                   -0.275767
# 1                        0.023188                   -0.049568
# 2                       -0.321955                   -0.321666
# 3                       -0.188433                   -0.376621
# 4                       -0.321955                   -0.257594
# ...                           ...                         ...
# 8068                     0.035392                    0.187740
# 8069                    -0.321955                   -0.250377
# 8070                    -0.321955                   -0.131755
# 8071                    -0.321955                   -0.376621
# 8072                    -0.202864                   -0.263772
#
#       VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 0                        -0.231135               0.495246
# 1                        -0.143622               0.763418
# 2                        -0.254022              -0.072272
# 3                        -0.098239              -0.447767
# 4                        -0.480336              -0.587862
# ...                            ...                    ...
# 8068                     -0.387371               0.409624
# 8069                     -0.189196              -0.805064
# 8070                     -0.413109              -0.758790
# 8071                     -0.480336               0.416342
# 8072                     -0.170517               0.195202
#
#       VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 0                             1.947946      3.632568
# 1                             0.238529      0.000000
# 2                             0.744326      0.000000
# 3                             0.534280      0.000000
# 4                             0.978342      0.000000
# ...                                ...           ...
# 8068                          0.672720      0.000000
# 8069                         -0.840787      0.000000
# 8070                         -1.119753      0.000000
# 8071                         -0.092956      0.000000
# 8072                          0.699308      0.000000
#
# [6547 rows x 38 columns]
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 0.55
# Root mean squared error of bins_2: 1.75
# Root mean squared error of bins_3: 3.94
# Root mean squared error of bins_4: 10.33
# Root mean squared error of bins_5: 18.55
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 0.34
# Root mean squared error of bins_2: 2.53
# Root mean squared error of bins_3: 6.37
# Root mean squared error of bins_4: 14.08
# Root mean squared error of bins_5: 46.31
# ----- Test  ------
# Mean absolute error: 1.91
# Mean squared error: 22.15
# Root mean squared error: 4.71
# Max error: 46.31
# Average Error: 0.15
# ---- Training -----
# Mean absolute error: 1.31
# Mean squared error: 12.81
# Root mean squared error: 3.58
# Max error: 50.71
# Average Error: -0.00
# Training score coefficient of determination for the model R^2: 0.871
# /tmp/ipykernel_92233/3041326752.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train=df_train.append(df_test[df_test['typhoon'] == test_list[num]])
#           typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 6800    vamco2020            0.271298             0.341942
# 6801    vamco2020            1.704740             0.525577
# 6802    vamco2020            0.701594             0.235326
# 6803    vamco2020            1.973405             0.990513
# 6804    vamco2020           -0.177600            -0.468540
# ...           ...                 ...                  ...
# 3298  kammuri2019           -0.547234            -0.392505
# 3299  kammuri2019            0.211310             0.702528
# 3300  kammuri2019            0.251819             0.368370
# 3301  kammuri2019            0.321951             1.024028
# 3302  kammuri2019           -0.870427            -0.841752
#
#       HAZ_rainfall_max_24h  HAZ_v_max  HAZ_v_max_3  HAZ_dis_track_min  \
# 6800              0.347412  -0.165874    -0.425196          -1.030969
# 6801              1.356928  -0.400363    -0.485447          -0.463913
# 6802              0.104512  -1.056908    -0.548821           0.533616
# 6803              1.697358  -0.304684    -0.463980          -0.708142
# 6804             -0.269478  -0.429711    -0.491240          -0.688008
# ...                    ...        ...          ...                ...
# 3298             -0.412940  -0.700915    -0.529557           1.082180
# 3299              0.430880   1.095505     0.533997          -0.478838
# 3300              0.340007   0.072635    -0.334333          -0.223672
# 3301              0.613993   1.551381     1.255283          -0.758349
# 3302             -0.846123  -0.561017    -0.513008           1.025970
#
#       GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 6800          -0.212592            5.102888        5.100166  ...
# 6801           1.257450            0.018098        0.018618  ...
# 6802          -0.629550           -0.351584       -0.351508  ...
# 6803           1.391090            1.694343        1.692870  ...
# 6804          -0.629550           -0.351584       -0.351508  ...
# ...                 ...                 ...             ...  ...
# 3298          -0.629550           -0.351584       -0.351508  ...
# 3299           2.545742           -0.195437       -0.195173  ...
# 3300           1.588878            0.055466        0.056031  ...
# 3301          -0.068261            1.095112        1.091582  ...
# 3302          -0.629550           -0.351584       -0.351508  ...
#
#       VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 6800                   -0.346117                 -0.433989
# 6801                    0.810547                  0.081525
# 6802                   -0.583838                 -0.481673
# 6803                   -0.357750                 -0.021535
# 6804                    0.132192                 -0.440675
# ...                          ...                       ...
# 3298                    0.041467                 -0.362893
# 3299                   -0.398538                  2.126573
# 3300                   -0.521536                  3.603347
# 3301                   -0.089043                  0.507463
# 3302                   -0.070763                 -0.402397
#
#       VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 6800                -0.758678                  -0.547616
# 6801                 0.138999                   1.441321
# 6802                -0.493736                  -0.547616
# 6803                 0.320360                  -0.547616
# 6804                -0.601943                  -0.280123
# ...                       ...                        ...
# 3298                -0.578227                  -0.130118
# 3299                 1.895188                   0.906086
# 3300                 1.607950                   0.709216
# 3301                 0.065949                   0.621402
# 3302                -0.135896                  -0.317607
#
#       VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 6800                    -0.321955                   -0.337477
# 6801                    -0.321955                   -0.376621
# 6802                    -0.321955                   -0.298837
# 6803                    -0.321955                   -0.274242
# 6804                    -0.321955                   -0.088408
# ...                           ...                         ...
# 3298                     0.059516                    0.008954
# 3299                    -0.056303                    0.462471
# 3300                    -0.202864                   -0.263772
# 3301                    -0.091894                    0.035161
# 3302                    -0.125805                   -0.314665
#
#       VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 6800                     -0.448095              -0.947447
# 6801                     -0.196669              -0.195917
# 6802                     -0.480336              -0.542169
# 6803                     -0.396013              -0.378751
# 6804                     -0.331972              -0.404409
# ...                            ...                    ...
# 3298                     -0.142916              -0.798363
# 3299                      0.141656               0.718603
# 3300                     -0.170517               0.195202
# 3301                     -0.220981              -0.766019
# 3302                     -0.429307               0.541929
#
#       VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 6800                         -1.150918      0.000000
# 6801                         -0.346559      0.000000
# 6802                          0.460075      0.000000
# 6803                         -0.166851      0.056513
# 6804                         -0.692202      0.000000
# ...                                ...           ...
# 3298                         -0.847003      2.321250
# 3299                          1.158742      8.175081
# 3300                          0.699308      1.038206
# 3301                         -0.329254     24.047333
# 3302                         -0.579196      0.000000
#
# [1524 rows x 38 columns]
#          typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 0     durian2006            0.429453             0.901680
# 1     durian2006           -1.002249            -1.004823
# 2     durian2006           -0.878043            -0.743714
# 3     durian2006           -0.952819            -0.845094
# 4     durian2006           -0.963981            -0.924749
# ...          ...                 ...                  ...
# 8070    noul2015           -0.980663            -0.983516
# 8071    noul2015           -0.979753            -0.878516
# 8072    noul2015           -0.812281            -0.832468
# 5268   nakri2019           -0.773676            -0.913927
# 5269   nakri2019           -0.827266            -0.903877
#
#       HAZ_rainfall_max_24h  HAZ_v_max  HAZ_v_max_3  HAZ_dis_track_min  \
# 0                 0.766418   1.592258     1.332271          -1.443648
# 1                -1.004232  -0.896964    -0.543458           1.423220
# 2                -0.829731  -0.777769    -0.536155           1.288795
# 3                -0.922008  -0.715243    -0.530911           1.066918
# 4                -0.936450  -0.793073    -0.537281           1.120728
# ...                    ...        ...          ...                ...
# 8070             -1.010444  -0.517240    -0.506472           0.640566
# 8071             -0.965113  -0.620712    -0.520841           0.719548
# 8072             -0.766925  -0.524996    -0.507681           0.733116
# 5268             -0.845051  -0.714947    -0.530884           1.496320
# 5269             -0.856201  -0.717084    -0.531081           1.519221
#
#       GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 0              0.781691            0.473193        0.474260  ...
# 1             -0.597476           -0.351584       -0.351508  ...
# 2              0.182983           -0.180756       -0.180475  ...
# 3             -0.629550           -0.351584       -0.351508  ...
# 4              2.321226           -0.303539       -0.303405  ...
# ...                 ...                 ...             ...  ...
# 8070          -0.597476           -0.339573       -0.339482  ...
# 8071          -0.629550           -0.351584       -0.351508  ...
# 8072           1.588878            0.055466        0.056031  ...
# 5268          -0.544020           -0.340907       -0.340819  ...
# 5269           1.984453           -0.055305       -0.054873  ...
#
#       VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 0                      -0.388957                  0.337830
# 1                       1.116440                 -0.106247
# 2                      -0.189419                 -0.292472
# 3                      -0.025027                 -0.289853
# 4                      -0.452411                 -0.240474
# ...                          ...                       ...
# 8070                   -0.178278                 -0.487495
# 8071                   -0.583838                 -0.486006
# 8072                   -0.521536                  3.603347
# 5268                   -0.226072                  0.079594
# 5269                   -0.499303                 -0.346608
#
#       VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 0                    2.004665                   3.945376
# 1                    0.038993                   1.914435
# 2                    0.174483                  -0.207586
# 3                   -0.416442                  -0.443236
# 4                    1.201765                  -0.547616
# ...                       ...                        ...
# 8070                -0.697345                  -0.446611
# 8071                -0.693494                  -0.547616
# 8072                 1.607950                   0.709216
# 5268                 2.640732                   0.165203
# 5269                 1.732524                  -0.310763
#
#       VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 0                       -0.321955                   -0.275767
# 1                        0.023188                   -0.049568
# 2                       -0.321955                   -0.321666
# 3                       -0.188433                   -0.376621
# 4                       -0.321955                   -0.257594
# ...                           ...                         ...
# 8070                    -0.321955                   -0.131755
# 8071                    -0.321955                   -0.376621
# 8072                    -0.202864                   -0.263772
# 5268                    -0.321955                    0.055398
# 5269                    -0.321955                   -0.300061
#
#       VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 0                        -0.231135               0.495246
# 1                        -0.143622               0.763418
# 2                        -0.254022              -0.072272
# 3                        -0.098239              -0.447767
# 4                        -0.480336              -0.587862
# ...                            ...                    ...
# 8070                     -0.413109              -0.758790
# 8071                     -0.480336               0.416342
# 8072                     -0.170517               0.195202
# 5268                     -0.124512              -0.627993
# 5269                     -0.480336              -0.013931
#
#       VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 0                             1.947946      3.632568
# 1                             0.238529      0.000000
# 2                             0.744326      0.000000
# 3                             0.534280      0.000000
# 4                             0.978342      0.000000
# ...                                ...           ...
# 8070                         -1.119753      0.000000
# 8071                         -0.092956      0.000000
# 8072                          0.699308      0.000000
# 5268                          0.814757      0.000000
# 5269                          0.935459      0.000000
#
# [6549 rows x 38 columns]
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 0.54
# Root mean squared error of bins_2: 1.72
# Root mean squared error of bins_3: 3.86
# Root mean squared error of bins_4: 10.18
# Root mean squared error of bins_5: 18.14
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 0.37
# Root mean squared error of bins_2: 2.54
# Root mean squared error of bins_3: 6.39
# Root mean squared error of bins_4: 14.06
# Root mean squared error of bins_5: 47.02
# ----- Test  ------
# Mean absolute error: 1.93
# Mean squared error: 22.25
# Root mean squared error: 4.72
# Max error: 47.02
# Average Error: 0.16
# ---- Training -----
# Mean absolute error: 1.30
# Mean squared error: 12.34
# Root mean squared error: 3.51
# Max error: 50.15
# Average Error: -0.00
# Training score coefficient of determination for the model R^2: 0.876
# /tmp/ipykernel_92233/3041326752.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train=df_train.append(df_test[df_test['typhoon'] == test_list[num]])
#            typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 6800     vamco2020            0.271298             0.341942
# 6801     vamco2020            1.704740             0.525577
# 6802     vamco2020            0.701594             0.235326
# 6803     vamco2020            1.973405             0.990513
# 6804     vamco2020           -0.177600            -0.468540
# ...            ...                 ...                  ...
# 6150  phanfone2019           -0.111479            -0.129864
# 6151  phanfone2019            0.332001             1.176933
# 6152  phanfone2019           -0.184071            -0.127822
# 6153  phanfone2019           -0.841489            -0.807587
# 6154  phanfone2019           -0.123004             0.042816
#
#       HAZ_rainfall_max_24h  HAZ_v_max  HAZ_v_max_3  HAZ_dis_track_min  \
# 6800              0.347412  -0.165874    -0.425196          -1.030969
# 6801              1.356928  -0.400363    -0.485447          -0.463913
# 6802              0.104512  -1.056908    -0.548821           0.533616
# 6803              1.697358  -0.304684    -0.463980          -0.708142
# 6804             -0.269478  -0.429711    -0.491240          -0.688008
# ...                    ...        ...          ...                ...
# 6150             -0.019362   0.677386     0.069735          -1.290539
# 6151              0.609517   0.619430     0.018408          -1.221040
# 6152             -0.050200   1.254219     0.757673          -1.330697
# 6153             -0.877416  -0.747821    -0.533775           1.220637
# 6154              0.054384   1.304115     0.833861          -1.177085
#
#       GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 6800          -0.212592            5.102888        5.100166  ...
# 6801           1.257450            0.018098        0.018618  ...
# 6802          -0.629550           -0.351584       -0.351508  ...
# 6803           1.391090            1.694343        1.692870  ...
# 6804          -0.629550           -0.351584       -0.351508  ...
# ...                 ...                 ...             ...  ...
# 6150          -0.629550           -0.351584       -0.351508  ...
# 6151          -0.629550           -0.351584       -0.351508  ...
# 6152          -0.597476           -0.343576       -0.343491  ...
# 6153           1.588878            0.055466        0.056031  ...
# 6154          -0.148445           -0.351584       -0.351508  ...
#
#       VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 6800                   -0.346117                 -0.433989
# 6801                    0.810547                  0.081525
# 6802                   -0.583838                 -0.481673
# 6803                   -0.357750                 -0.021535
# 6804                    0.132192                 -0.440675
# ...                          ...                       ...
# 6150                    1.051635                 -0.284212
# 6151                    1.480898                 -0.482420
# 6152                    1.267365                 -0.199596
# 6153                   -0.521536                  3.603347
# 6154                   -0.583838                  0.084792
#
#       VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 6800                -0.758678                  -0.547616
# 6801                 0.138999                   1.441321
# 6802                -0.493736                  -0.547616
# 6803                 0.320360                  -0.547616
# 6804                -0.601943                  -0.280123
# ...                       ...                        ...
# 6150                -0.621690                   0.016363
# 6151                -0.763560                  -0.119093
# 6152                 1.069469                   2.394697
# 6153                 1.607950                   0.709216
# 6154                 0.994492                  -0.547616
#
#       VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 6800                    -0.321955                   -0.337477
# 6801                    -0.321955                   -0.376621
# 6802                    -0.321955                   -0.298837
# 6803                    -0.321955                   -0.274242
# 6804                    -0.321955                   -0.088408
# ...                           ...                         ...
# 6150                     0.399481                    0.534875
# 6151                     0.555104                    0.489096
# 6152                    -0.128941                    0.415934
# 6153                    -0.202864                   -0.263772
# 6154                    -0.321955                   -0.042275
#
#       VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 6800                     -0.448095              -0.947447
# 6801                     -0.196669              -0.195917
# 6802                     -0.480336              -0.542169
# 6803                     -0.396013              -0.378751
# 6804                     -0.331972              -0.404409
# ...                            ...                    ...
# 6150                      1.208821               0.277600
# 6151                      0.432344              -0.863902
# 6152                      0.423504               1.747884
# 6153                     -0.170517               0.195202
# 6154                     -0.480336               1.549105
#
#       VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 6800                         -1.150918      0.000000
# 6801                         -0.346559      0.000000
# 6802                          0.460075      0.000000
# 6803                         -0.166851      0.056513
# 6804                         -0.692202      0.000000
# ...                                ...           ...
# 6150                         -0.019327      3.144654
# 6151                          0.204791      5.982988
# 6152                          1.435476      4.072017
# 6153                          0.699308      0.000000
# 6154                          1.825594      2.860658
#
# [1194 rows x 38 columns]
#           typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 0      durian2006            0.429453             0.901680
# 1      durian2006           -1.002249            -1.004823
# 2      durian2006           -0.878043            -0.743714
# 3      durian2006           -0.952819            -0.845094
# 4      durian2006           -0.963981            -0.924749
# ...           ...                 ...                  ...
# 3298  kammuri2019           -0.547234            -0.392505
# 3299  kammuri2019            0.211310             0.702528
# 3300  kammuri2019            0.251819             0.368370
# 3301  kammuri2019            0.321951             1.024028
# 3302  kammuri2019           -0.870427            -0.841752
#
#       HAZ_rainfall_max_24h  HAZ_v_max  HAZ_v_max_3  HAZ_dis_track_min  \
# 0                 0.766418   1.592258     1.332271          -1.443648
# 1                -1.004232  -0.896964    -0.543458           1.423220
# 2                -0.829731  -0.777769    -0.536155           1.288795
# 3                -0.922008  -0.715243    -0.530911           1.066918
# 4                -0.936450  -0.793073    -0.537281           1.120728
# ...                    ...        ...          ...                ...
# 3298             -0.412940  -0.700915    -0.529557           1.082180
# 3299              0.430880   1.095505     0.533997          -0.478838
# 3300              0.340007   0.072635    -0.334333          -0.223672
# 3301              0.613993   1.551381     1.255283          -0.758349
# 3302             -0.846123  -0.561017    -0.513008           1.025970
#
#       GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 0              0.781691            0.473193        0.474260  ...
# 1             -0.597476           -0.351584       -0.351508  ...
# 2              0.182983           -0.180756       -0.180475  ...
# 3             -0.629550           -0.351584       -0.351508  ...
# 4              2.321226           -0.303539       -0.303405  ...
# ...                 ...                 ...             ...  ...
# 3298          -0.629550           -0.351584       -0.351508  ...
# 3299           2.545742           -0.195437       -0.195173  ...
# 3300           1.588878            0.055466        0.056031  ...
# 3301          -0.068261            1.095112        1.091582  ...
# 3302          -0.629550           -0.351584       -0.351508  ...
#
#       VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 0                      -0.388957                  0.337830
# 1                       1.116440                 -0.106247
# 2                      -0.189419                 -0.292472
# 3                      -0.025027                 -0.289853
# 4                      -0.452411                 -0.240474
# ...                          ...                       ...
# 3298                    0.041467                 -0.362893
# 3299                   -0.398538                  2.126573
# 3300                   -0.521536                  3.603347
# 3301                   -0.089043                  0.507463
# 3302                   -0.070763                 -0.402397
#
#       VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 0                    2.004665                   3.945376
# 1                    0.038993                   1.914435
# 2                    0.174483                  -0.207586
# 3                   -0.416442                  -0.443236
# 4                    1.201765                  -0.547616
# ...                       ...                        ...
# 3298                -0.578227                  -0.130118
# 3299                 1.895188                   0.906086
# 3300                 1.607950                   0.709216
# 3301                 0.065949                   0.621402
# 3302                -0.135896                  -0.317607
#
#       VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 0                       -0.321955                   -0.275767
# 1                        0.023188                   -0.049568
# 2                       -0.321955                   -0.321666
# 3                       -0.188433                   -0.376621
# 4                       -0.321955                   -0.257594
# ...                           ...                         ...
# 3298                     0.059516                    0.008954
# 3299                    -0.056303                    0.462471
# 3300                    -0.202864                   -0.263772
# 3301                    -0.091894                    0.035161
# 3302                    -0.125805                   -0.314665
#
#       VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 0                        -0.231135               0.495246
# 1                        -0.143622               0.763418
# 2                        -0.254022              -0.072272
# 3                        -0.098239              -0.447767
# 4                        -0.480336              -0.587862
# ...                            ...                    ...
# 3298                     -0.142916              -0.798363
# 3299                      0.141656               0.718603
# 3300                     -0.170517               0.195202
# 3301                     -0.220981              -0.766019
# 3302                     -0.429307               0.541929
#
#       VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 0                             1.947946      3.632568
# 1                             0.238529      0.000000
# 2                             0.744326      0.000000
# 3                             0.534280      0.000000
# 4                             0.978342      0.000000
# ...                                ...           ...
# 3298                         -0.847003      2.321250
# 3299                          1.158742      8.175081
# 3300                          0.699308      1.038206
# 3301                         -0.329254     24.047333
# 3302                         -0.579196      0.000000
#
# [6879 rows x 38 columns]
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 0.55
# Root mean squared error of bins_2: 1.77
# Root mean squared error of bins_3: 3.85
# Root mean squared error of bins_4: 10.33
# Root mean squared error of bins_5: 19.28
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 0.38
# Root mean squared error of bins_2: 2.29
# Root mean squared error of bins_3: 3.79
# Root mean squared error of bins_4: 14.32
# Root mean squared error of bins_5: 57.78
# ----- Test  ------
# Mean absolute error: 1.50
# Mean squared error: 16.05
# Root mean squared error: 4.01
# Max error: 57.78
# Average Error: -0.21
# ---- Training -----
# Mean absolute error: 1.37
# Mean squared error: 13.22
# Root mean squared error: 3.64
# Max error: 53.25
# Average Error: -0.00
# Training score coefficient of determination for the model R^2: 0.862
# /tmp/ipykernel_92233/3041326752.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train=df_train.append(df_test[df_test['typhoon'] == test_list[num]])
#            typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 6800     vamco2020            0.271298             0.341942
# 6801     vamco2020            1.704740             0.525577
# 6802     vamco2020            0.701594             0.235326
# 6803     vamco2020            1.973405             0.990513
# 6804     vamco2020           -0.177600            -0.468540
# ...            ...                 ...                  ...
# 7411  vongfong2020           -0.707017            -0.809889
# 7412  vongfong2020           -0.387592            -0.615318
# 7413  vongfong2020           -0.850392            -0.901455
# 7414  vongfong2020           -0.724407            -0.869603
# 7415  vongfong2020           -0.840635            -0.878516
#
#       HAZ_rainfall_max_24h  HAZ_v_max  HAZ_v_max_3  HAZ_dis_track_min  \
# 6800              0.347412  -0.165874    -0.425196          -1.030969
# 6801              1.356928  -0.400363    -0.485447          -0.463913
# 6802              0.104512  -1.056908    -0.548821           0.533616
# 6803              1.697358  -0.304684    -0.463980          -0.708142
# 6804             -0.269478  -0.429711    -0.491240          -0.688008
# ...                    ...        ...          ...                ...
# 7411             -0.811752  -1.195528    -0.550611           1.449144
# 7412             -0.413769  -0.826999    -0.539571          -0.794284
# 7413             -0.941588  -0.882994    -0.542767          -0.280569
# 7414             -0.773343  -0.875264    -0.542367          -0.291813
# 7415             -0.972080  -1.227200    -0.550777           0.684297
#
#       GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 6800          -0.212592            5.102888        5.100166  ...
# 6801           1.257450            0.018098        0.018618  ...
# 6802          -0.629550           -0.351584       -0.351508  ...
# 6803           1.391090            1.694343        1.692870  ...
# 6804          -0.629550           -0.351584       -0.351508  ...
# ...                 ...                 ...             ...  ...
# 7411          -0.629550           -0.351584       -0.351508  ...
# 7412          -0.629550           -0.351584       -0.351508  ...
# 7413          -0.576093           -0.351584       -0.351508  ...
# 7414          -0.629550           -0.351584       -0.351508  ...
# 7415          -0.629550           -0.351584       -0.351508  ...
#
#       VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 6800                   -0.346117                 -0.433989
# 6801                    0.810547                  0.081525
# 6802                   -0.583838                 -0.481673
# 6803                   -0.357750                 -0.021535
# 6804                    0.132192                 -0.440675
# ...                          ...                       ...
# 7411                   -0.440446                 -0.457393
# 7412                    0.041467                 -0.362893
# 7413                   -0.098151                  0.110955
# 7414                    1.480898                 -0.482420
# 7415                   -0.070763                 -0.402397
#
#       VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 6800                -0.758678                  -0.547616
# 6801                 0.138999                   1.441321
# 6802                -0.493736                  -0.547616
# 6803                 0.320360                  -0.547616
# 6804                -0.601943                  -0.280123
# ...                       ...                        ...
# 7411                -0.725974                  -0.547616
# 7412                -0.578227                  -0.130118
# 7413                 0.299725                  -0.426655
# 7414                -0.763560                  -0.119093
# 7415                -0.135896                  -0.317607
#
#       VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 6800                    -0.321955                   -0.337477
# 6801                    -0.321955                   -0.376621
# 6802                    -0.321955                   -0.298837
# 6803                    -0.321955                   -0.274242
# 6804                    -0.321955                   -0.088408
# ...                           ...                         ...
# 7411                    -0.321955                   -0.311689
# 7412                     0.059516                    0.008954
# 7413                    -0.321955                   -0.213708
# 7414                     0.555104                    0.489096
# 7415                    -0.125805                   -0.314665
#
#       VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 6800                     -0.448095              -0.947447
# 6801                     -0.196669              -0.195917
# 6802                     -0.480336              -0.542169
# 6803                     -0.396013              -0.378751
# 6804                     -0.331972              -0.404409
# ...                            ...                    ...
# 7411                     -0.426856               0.588077
# 7412                     -0.142916              -0.798363
# 7413                     -0.399827              -0.422407
# 7414                      0.432344              -0.863902
# 7415                     -0.429307               0.541929
#
#       VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 6800                         -1.150918      0.000000
# 6801                         -0.346559      0.000000
# 6802                          0.460075      0.000000
# 6803                         -0.166851      0.056513
# 6804                         -0.692202      0.000000
# ...                                ...           ...
# 7411                         -0.134781      0.000000
# 7412                         -0.847003      0.106418
# 7413                          0.352310      0.000000
# 7414                          0.204791      0.000000
# 7415                         -0.579196      0.000000
#
# [975 rows x 38 columns]
#            typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 0       durian2006            0.429453             0.901680
# 1       durian2006           -1.002249            -1.004823
# 2       durian2006           -0.878043            -0.743714
# 3       durian2006           -0.952819            -0.845094
# 4       durian2006           -0.963981            -0.924749
# ...            ...                 ...                  ...
# ...
# 5150                    -0.112919                   -0.145529
# 5151                    -0.321955                   -0.271035
# 5152                    -0.154620                   -0.323766
# 5153                     0.059516                    0.008954
# 5154                    -0.056303                    0.462471
#
#       VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 0                        -0.231135               0.495246
# 1                        -0.143622               0.763418
# 2                        -0.254022              -0.072272
# 3                        -0.098239              -0.447767
# 4                        -0.480336              -0.587862
# ...                            ...                    ...
# 5150                      0.172241              -0.015434
# 5151                     -0.480336               0.777320
# 5152                     -0.393270              -0.030760
# 5153                     -0.142916              -0.798363
# 5154                      0.141656               0.718603
#
#       VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 0                             1.947946      3.632568
# 1                             0.238529      0.000000
# 2                             0.744326      0.000000
# 3                             0.534280      0.000000
# 4                             0.978342      0.000000
# ...                                ...           ...
# 5150                          0.185492      0.218679
# 5151                         -0.460388      0.014571
# 5152                          0.148559      0.962801
# 5153                         -0.847003      1.084137
# 5154                          1.158742      2.709588
#
# [7545 rows x 38 columns]
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 0.58
# Root mean squared error of bins_2: 1.81
# Root mean squared error of bins_3: 3.73
# Root mean squared error of bins_4: 10.72
# Root mean squared error of bins_5: 19.20
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 0.60
# Root mean squared error of bins_2: 0.84
# Root mean squared error of bins_3: 5.37
# Root mean squared error of bins_4: 13.15
# Root mean squared error of bins_5: -1.00
# ----- Test  ------
# Mean absolute error: 1.56
# Mean squared error: 14.78
# Root mean squared error: 3.84
# Max error: 32.36
# Average Error: -0.26
# ---- Training -----
# Mean absolute error: 1.38
# Mean squared error: 13.05
# Root mean squared error: 3.61
# Max error: 51.45
# Average Error: -0.00
# Training score coefficient of determination for the model R^2: 0.854
# /tmp/ipykernel_92233/3041326752.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train=df_train.append(df_test[df_test['typhoon'] == test_list[num]])
#         typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 6800  vamco2020            0.271298             0.341942
# 6801  vamco2020            1.704740             0.525577
# 6802  vamco2020            0.701594             0.235326
# 6803  vamco2020            1.973405             0.990513
# 6804  vamco2020           -0.177600            -0.468540
# ...         ...                 ...                  ...
# 7093  vamco2020            0.034514            -0.056893
# 7094  vamco2020           -0.090449            -0.451829
# 7095  vamco2020            0.689663             0.676997
# 7096  vamco2020            1.973764             1.283760
# 7097  vamco2020            0.129956            -0.075832
#
#       HAZ_rainfall_max_24h  HAZ_v_max  HAZ_v_max_3  HAZ_dis_track_min  \
# 6800              0.347412  -0.165874    -0.425196          -1.030969
# 6801              1.356928  -0.400363    -0.485447          -0.463913
# 6802              0.104512  -1.056908    -0.548821           0.533616
# 6803              1.697358  -0.304684    -0.463980          -0.708142
# 6804             -0.269478  -0.429711    -0.491240          -0.688008
# ...                    ...        ...          ...                ...
# 7093             -0.108753   0.014783    -0.359428          -0.995108
# 7094             -0.232338  -0.482835    -0.500840          -0.633061
# 7095              0.376788  -0.988594    -0.547057           0.225028
# 7096              1.632079   0.352291    -0.181868          -1.052706
# 7097             -0.068636   0.252927    -0.242264          -1.096413
#
#       GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 6800          -0.212592            5.102888        5.100166  ...
# 6801           1.257450            0.018098        0.018618  ...
# 6802          -0.629550           -0.351584       -0.351508  ...
# 6803           1.391090            1.694343        1.692870  ...
# 6804          -0.629550           -0.351584       -0.351508  ...
# ...                 ...                 ...             ...  ...
# 7093          -0.629550           -0.351584       -0.351508  ...
# 7094          -0.629550           -0.351584       -0.351508  ...
# 7095          -0.597476           -0.339573       -0.339482  ...
# 7096           1.588878            0.055466        0.056031  ...
# 7097          -0.629550           -0.351584       -0.351508  ...
#
#       VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 6800                   -0.346117                 -0.433989
# 6801                    0.810547                  0.081525
# 6802                   -0.583838                 -0.481673
# 6803                   -0.357750                 -0.021535
# 6804                    0.132192                 -0.440675
# ...                          ...                       ...
# 7093                    0.041467                 -0.362893
# 7094                   -0.165655                 -0.388452
# 7095                   -0.178278                 -0.487495
# 7096                   -0.521536                  3.603347
# 7097                   -0.401693                 -0.339512
#
#       VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 6800                -0.758678                  -0.547616
# 6801                 0.138999                   1.441321
# 6802                -0.493736                  -0.547616
# 6803                 0.320360                  -0.547616
# 6804                -0.601943                  -0.280123
# ...                       ...                        ...
# 7093                -0.578227                  -0.130118
# 7094                -0.583216                  -0.422637
# 7095                -0.697345                  -0.446611
# 7096                 1.607950                   0.709216
# 7097                -0.419465                  -0.302653
#
#       VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 6800                    -0.321955                   -0.337477
# 6801                    -0.321955                   -0.376621
# 6802                    -0.321955                   -0.298837
# 6803                    -0.321955                   -0.274242
# 6804                    -0.321955                   -0.088408
# ...                           ...                         ...
# 7093                     0.059516                    0.008954
# 7094                    -0.321955                   -0.250377
# 7095                    -0.321955                   -0.131755
# 7096                    -0.202864                   -0.263772
# 7097                    -0.217504                   -0.211660
#
#       VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 6800                     -0.448095              -0.947447
# 6801                     -0.196669              -0.195917
# 6802                     -0.480336              -0.542169
# 6803                     -0.396013              -0.378751
# 6804                     -0.331972              -0.404409
# ...                            ...                    ...
# 7093                     -0.142916              -0.798363
# 7094                     -0.189196              -0.805064
# 7095                     -0.413109              -0.758790
# 7096                     -0.170517               0.195202
# 7097                     -0.181429              -1.018213
#
#       VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 6800                         -1.150918      0.000000
# 6801                         -0.346559      0.000000
# 6802                          0.460075      0.000000
# 6803                         -0.166851      0.056513
# 6804                         -0.692202      0.000000
# ...                                ...           ...
# 7093                         -0.847003      0.000000
# 7094                         -0.840787      0.000000
# 7095                         -1.119753      0.045055
# 7096                          0.699308      7.277824
# 7097                         -0.380716      0.546349
#
# [298 rows x 38 columns]
#          typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 0     durian2006            0.429453             0.901680
# 1     durian2006           -1.002249            -1.004823
# 2     durian2006           -0.878043            -0.743714
# 3     durian2006           -0.952819            -0.845094
# 4     durian2006           -0.963981            -0.924749
# ...          ...                 ...                  ...
# 1726    goni2020           -0.336838            -0.100899
# 1727    goni2020           -0.841444            -0.754854
# 1728    goni2020            0.325490             0.996826
# 1729    goni2020           -0.388322            -0.198812
# 1730    goni2020            0.503532             0.942144
#
#       HAZ_rainfall_max_24h  HAZ_v_max  HAZ_v_max_3  HAZ_dis_track_min  \
# 0                 0.766418   1.592258     1.332271          -1.443648
# 1                -1.004232  -0.896964    -0.543458           1.423220
# 2                -0.829731  -0.777769    -0.536155           1.288795
# 3                -0.922008  -0.715243    -0.530911           1.066918
# 4                -0.936450  -0.793073    -0.537281           1.120728
# ...                    ...        ...          ...                ...
# 1726             -0.362394   0.580991    -0.014023          -1.406280
# 1727             -0.842499  -0.396352    -0.484627          -0.000070
# 1728              0.375148   0.743019     0.131482          -1.171604
# 1729             -0.397219  -0.672655    -0.526711          -0.748506
# 1730              0.745861   2.956683     5.324362          -1.426701
#
#       GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 0              0.781691            0.473193        0.474260  ...
# 1             -0.597476           -0.351584       -0.351508  ...
# 2              0.182983           -0.180756       -0.180475  ...
# 3             -0.629550           -0.351584       -0.351508  ...
# 4              2.321226           -0.303539       -0.303405  ...
# ...                 ...                 ...             ...  ...
# 1726           0.476991           -0.031282       -0.030822  ...
# 1727          -0.437108           -0.351584       -0.351508  ...
# 1728           2.545742           -0.195437       -0.195173  ...
# 1729           1.588878            0.055466        0.056031  ...
# 1730          -0.068261            1.095112        1.091582  ...
#
#       VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 0                      -0.388957                  0.337830
# 1                       1.116440                 -0.106247
# 2                      -0.189419                 -0.292472
# 3                      -0.025027                 -0.289853
# 4                      -0.452411                 -0.240474
# ...                          ...                       ...
# 1726                   -0.356972                  0.133439
# 1727                   -0.142226                 -0.290938
# 1728                   -0.398538                  2.126573
# 1729                   -0.521536                  3.603347
# 1730                   -0.089043                  0.507463
#
#       VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 0                    2.004665                   3.945376
# 1                    0.038993                   1.914435
# 2                    0.174483                  -0.207586
# 3                   -0.416442                  -0.443236
# 4                    1.201765                  -0.547616
# ...                       ...                        ...
# 1726                 0.769383                   0.542055
# 1727                -0.307382                  -0.418504
# 1728                 1.895188                   0.906086
# 1729                 1.607950                   0.709216
# 1730                 0.065949                   0.621402
#
#       VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 0                       -0.321955                   -0.275767
# 1                        0.023188                   -0.049568
# 2                       -0.321955                   -0.321666
# 3                       -0.188433                   -0.376621
# 4                       -0.321955                   -0.257594
# ...                           ...                         ...
# 1726                     0.049751                    0.034305
# 1727                    -0.211849                   -0.167952
# 1728                    -0.056303                    0.462471
# 1729                    -0.202864                   -0.263772
# 1730                    -0.091894                    0.035161
#
#       VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 0                        -0.231135               0.495246
# 1                        -0.143622               0.763418
# 2                        -0.254022              -0.072272
# 3                        -0.098239              -0.447767
# 4                        -0.480336              -0.587862
# ...                            ...                    ...
# 1726                     -0.335285              -0.221890
# 1727                     -0.193891               1.197934
# 1728                      0.141656               0.718603
# 1729                     -0.170517               0.195202
# 1730                     -0.220981              -0.766019
#
#       VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 0                             1.947946      3.632568
# 1                             0.238529      0.000000
# 2                             0.744326      0.000000
# 3                             0.534280      0.000000
# 4                             0.978342      0.000000
# ...                                ...           ...
# 1726                          0.087693      0.016202
# 1727                          0.219293      0.000000
# 1728                          1.158742     11.000463
# 1729                          0.699308      0.436047
# 1730                         -0.329254     35.178500
#
# [7775 rows x 38 columns]
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 0.55
# Root mean squared error of bins_2: 1.93
# Root mean squared error of bins_3: 3.67
# Root mean squared error of bins_4: 10.62
# Root mean squared error of bins_5: 20.00
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 0.72
# Root mean squared error of bins_2: 0.77
# Root mean squared error of bins_3: 5.24
# Root mean squared error of bins_4: 14.12
# Root mean squared error of bins_5: -1.00
# ----- Test  ------
# Mean absolute error: 1.12
# Mean squared error: 9.30
# Root mean squared error: 3.05
# Max error: 31.56
# Average Error: 0.05
# ---- Training -----
# Mean absolute error: 1.40
# Mean squared error: 13.39
# Root mean squared error: 3.66
# Max error: 52.90
# Average Error: -0.00
# Training score coefficient of determination for the model R^2: 0.848
# [4.70615754732764,
#  4.717290537610746,
#  4.005859335793025,
#  3.7401859095515593,
#  3.5339180031131523,
#  3.6199862953514708,
#  3.844579065163768,
#  3.048871001494315]

# %%
#Plot of RMSE estimation according to 8 different test sets

x = ['nakri2019', 'kammuri2019', 'phanfone2019', 'vongfong2020', 'saudel2020', 'molave2020', 'goni2020', 'vamco2020']
y = rmse_test_list

plt.scatter(x, y, cmap='viridis')

#obtain m (slope) and b(intercept) of linear regression line
#m, b = np.polyfit(x, y, 1)
plt.plot(x, y, color='orange')


plt.xlabel("Typhoon's Date", fontsize=10)
plt.ylabel('RMSE_Test', fontsize=10)
plt.title("Typhoon's Date vs Performance Measure")

np.rot90(plt.xticks(rotation=70, fontsize=12))
plt.yticks(np.arange(2.5,5.0,step=0.25))
plt.show()

# %% [markdown]
# Plots Per bins

# %%
import matplotlib.pyplot as plt
import numpy as np

#Plot RMSE estimation of bin_1 based on 8 different test sets    
x = ['nakri2019', 'kammuri2019', 'phanfone2019', 'vongfong2020', 'saudel2020', 'molave2020', 'goni2020', 'vamco2020']
y = rmse_list_1

plt.scatter(x, y, cmap='viridis')
plt.plot(x, y, color='r')

plt.xlabel("Typhoon's Date", fontsize=10)
plt.ylabel('RMSE_Test', fontsize=10)
plt.title("Typhoon's Date vs Performance Measure")

np.rot90(plt.xticks(rotation=70, fontsize=12))
plt.yticks(np.arange(0.0,1.0,step=0.25))
plt.show()


#Plot RMSE estimation of bin_2 based on 8 different test sets  
x = ['nakri2019', 'kammuri2019', 'phanfone2019', 'vongfong2020', 'saudel2020', 'molave2020', 'goni2020', 'vamco2020']
y = rmse_list_2

plt.scatter(x, y, cmap='viridis')
plt.plot(x, y, color='r')

plt.xlabel("Typhoon's Date", fontsize=10)
plt.ylabel('RMSE_Test', fontsize=10)
plt.title("Typhoon's Date vs Performance Measure-bin2:(0,1]")

np.rot90(plt.xticks(rotation=70, fontsize=12))
#plt.yticks(np.arange(0.0,1.0,step=0.25))
plt.show()


#Plot RMSE estimation of bin_3 based on 8 different test sets    
x = ['nakri2019', 'kammuri2019', 'phanfone2019', 'vongfong2020', 'saudel2020', 'molave2020', 'goni2020', 'vamco2020']
y = rmse_list_3

plt.scatter(x, y, cmap='viridis')
plt.plot(x, y, color='r')

plt.xlabel("Typhoon's Date", fontsize=10)
plt.ylabel('RMSE_Test', fontsize=10)
plt.title("Typhoon's Date vs Performance Measure-bin3:(1,10]")

np.rot90(plt.xticks(rotation=70, fontsize=12))
#plt.yticks(np.arange(0.0,1.0,step=0.25))
plt.show()


#Plot RMSE estimation of bin_4 based on 8 different test sets    
x = ['nakri2019', 'kammuri2019', 'phanfone2019', 'vongfong2020', 'saudel2020', 'molave2020', 'goni2020', 'vamco2020']
y = rmse_list_4

plt.scatter(x, y, cmap='viridis')
plt.plot(x, y, color='r')

plt.xlabel("Typhoon's Date", fontsize=10)
plt.ylabel('RMSE_Test', fontsize=10)
plt.title("Typhoon's Date vs Performance Measure bin_4:(10,50]")

np.rot90(plt.xticks(rotation=70, fontsize=12))
plt.yticks(np.arange(12.5,14.75,step=0.5))
plt.show()


#Plot RMSE estimation of bin_5 based on 8 different test sets
x = ['nakri2019', 'kammuri2019', 'phanfone2019', 'vongfong2020', 'saudel2020', 'molave2020', 'goni2020', 'vamco2020']
y = rmse_list_5


index = [i for i,j in enumerate(y) if j == -1]
for i in range(len(index)):
    a=index[0]
    typhoon_name = x[a]
    x.remove(typhoon_name)
    y.remove(-1)

plt.scatter(x, y, cmap='viridis')
plt.plot(x, y, color='r')

plt.xlabel("Typhoon's Date", fontsize=10)
plt.ylabel('RMSE_Test', fontsize=10)
plt.title("Typhoon's Date vs Performance Measure bin_5:(50,100]")

np.rot90(plt.xticks(rotation=70, fontsize=12))
#plt.yticks(np.arange(46,59,step=1))
plt.show()

# %%
"""
Due to the fact that the calculated RMSE for the first three bins are more or less in the same range so we plot them
in one figure.
Plot RMSE estimation of bin(1 & 2 & 3) based on 8 different test sets
"""

x = ['nakri2019', 'kammuri2019', 'phanfone2019', 'vongfong2020', 'saudel2020', 'molave2020', 'goni2020', 'vamco2020']
y = rmse_list_1
y2 = rmse_list_2
y3 = rmse_list_3


plt.plot(x, y, 'g', label='Line y1')
plt.plot(x, y2, 'r', label='Line y2')
plt.plot(x, y3, 'b', label='Line y3')

plt.scatter(x, y, cmap='viridis')
plt.scatter(x, y2, cmap='viridis')
plt.scatter(x, y3, cmap='viridis')


#create legend
labels= ["bin1","bin2","bin3"]
plt.legend(labels)


plt.xlabel("Typhoon's Date", fontsize=10)
plt.ylabel('RMSE_Test', fontsize=10)
plt.title("Typhoon's Date vs Performance Measure bin_1:[0], bin_2:(0,1], bin_3:(1,10]")

np.rot90(plt.xticks(rotation=70, fontsize=12))
plt.yticks(np.arange(0.0,7.0,step=0.5))
plt.show()
