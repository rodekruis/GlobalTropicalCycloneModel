# %% [markdown]
# For XGBoost model before and after ReducedOverfitting.
#
# The RMSE and Weighted RMSE estimation per bins for dataset where damaged values are greater than 10.

# %%
# %load_ext jupyter_black

# %%
import statistics
import math
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, max_error

from utils import get_clean_dataset

# %%
df = get_clean_dataset()

# %%
df = df[df['DAM_perc_dmg'] > 10]
df
# Out:
#             typhoon  HAZ_rainfall_Total  HAZ_rainfall_max_6h  \
# 39       durian2006          128.785714             7.623810
# 40       durian2006          137.600000            10.846970
# 67       durian2006          236.800000            23.022917
# 79       durian2006          166.710000            11.723333
# 80       durian2006          218.475000            20.925000
# ...             ...                 ...                  ...
# 23423  vongfong2020          254.525000            23.410417
# 23461  vongfong2020          255.687500            21.612500
# 23877  vongfong2020          258.160000            18.825000
# 23958  vongfong2020          212.800000            15.002381
# 25363   meranti2016          281.550000            18.195833
#
#        HAZ_rainfall_max_24h  HAZ_v_max    HAZ_v_max_3  HAZ_dis_track_min  \
# 39                 4.991964  67.297247  304783.811133          16.034037
# 40                 5.338258  54.729980  163936.581742          14.053818
# 67                 9.250000  68.469676  320992.456376          28.294582
# 79                 6.353750  64.000391  262148.800838          20.452986
# 80                 8.506771  76.858109  454013.837540          16.963048
# ...                     ...        ...            ...                ...
# 23423              9.786458  47.579864  107713.362477           0.993916
# 23461              9.660417  48.218915  112112.054833           7.514910
# 23877              9.100833  49.041771  117950.133023           0.746003
# 23958              7.574107  43.430665   81919.906658           1.708735
# 25363             10.761806  73.139531  391251.952379           4.402487
#
#        GEN_landslide_per  GEN_stormsurge_per  GEN_Bu_p_inSSA  ...  \
# 39                  0.61                0.00            0.00  ...
# 40                  2.58                7.27            7.27  ...
# 67                  5.76                1.26            1.26  ...
# 79                  0.97                0.03            0.03  ...
# 80                  6.14                2.50            2.50  ...
# ...                  ...                 ...             ...  ...
# 23423               0.00                0.00            0.00  ...
# 23461               0.00                0.00            0.00  ...
# 23877               0.00                0.00            0.00  ...
# 23958               0.00                0.00            0.00  ...
# 25363               5.57                0.22            0.22  ...
#
#        VUL_StrongRoof_SalvageWall  VUL_LightRoof_StrongWall  \
# 39                       0.027878                 13.639532
# 40                       0.072745                  2.982541
# 67                       0.250179                  5.611151
# 79                       0.010288                  9.526749
# 80                       0.420633                  4.250609
# ...                           ...                       ...
# 23423                    0.348635                  0.232423
# 23461                    0.121556                  4.821718
# 23877                    0.980693                  2.666258
# 23958                    0.000000                  0.880734
# 25363                    0.000000                  4.830918
#
#        VUL_LightRoof_LightWall  VUL_LightRoof_SalvageWall  \
# 39                   25.425146                   0.069696
# 40                   24.709020                   0.072745
# 67                   31.486776                   0.321658
# 79                   40.843621                   0.041152
# 80                   19.216294                   0.420633
# ...                        ...                        ...
# 23423                39.628123                   0.232423
# 23461                51.782820                   0.526742
# 23877                38.768005                   0.796813
# 23958                54.311927                   0.183486
# 25363                13.285024                   0.000000
#
#        VUL_SalvagedRoof_StrongWall  VUL_SalvagedRoof_LightWall  \
# 39                        0.000000                    0.006970
# 40                        0.048497                    0.181862
# 67                        0.035740                    0.071480
# 79                        0.020576                    0.000000
# 80                        0.066416                    0.088554
# ...                            ...                         ...
# 23423                     0.000000                    0.116212
# 23461                     0.000000                    0.121556
# 23877                     0.122587                    0.367760
# 23958                     0.000000                    0.073394
# 25363                     0.000000                    0.000000
#
#        VUL_SalvagedRoof_SalvageWall  VUL_vulnerable_groups  \
# 39                         0.006970               2.458422
# 40                         0.218235               2.364638
# 67                         0.178699               3.152242
# 79                         0.010288               2.276694
# 80                         0.221386               1.762301
# ...                             ...                    ...
# 23423                      0.058106               2.409639
# 23461                      0.283630               7.043011
# 23877                      0.337113               4.078437
# 23958                      0.293578               5.823910
# 25363                      0.000000               0.906871
#
#        VUL_pantawid_pamilya_beneficiary  DAM_perc_dmg
# 39                            28.331475     39.364371
# 40                            40.058196     16.585839
# 67                            31.665475     47.140815
# 79                            30.884774     50.154321
# 80                            22.647775     51.073721
# ...                                 ...           ...
# 23423                         44.973852     18.651947
# 23461                         27.350081     74.230146
# 23877                         34.293595     27.244867
# 23958                         39.559633     16.183486
# 25363                          7.004831     20.772947
#
# [495 rows x 38 columns]

# %%
#The Second chosen bins
bins2= [10.0009, 20, 50, 101]
samples_per_bin2, binsP2 = np.histogram(df['DAM_perc_dmg'], bins=bins2)
plt.xlabel("Damage Values")
plt.ylabel("Frequency")
plt.plot(binsP2[1:],samples_per_bin2)

# %%
print(samples_per_bin2)
print(binsP2)
# Out:
# [214 191  90]
# [ 10.0009  20.      50.     101.    ]

# %%
#df['DAM_perc_dmg'].value_counts(bins=binsP2)

# %%
bin_index2=np.digitize(df['DAM_perc_dmg'], bins=binsP2)

# %%
y_input_strat=bin_index2

# %%
#the Beginning time to run the model 20 times
import datetime
now = datetime.datetime.now()
print ("Current date and time : ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current date and time :
# 2022-11-10 01:03:23

# %%
#Define empty lists for bins results(test)
test_RMSE_list_bin1=[]
test_RMSE_list_bin2=[]
test_RMSE_list_bin3=[]


#Define empty lists for bins results(train)
train_RMSE_list_bin1=[]
train_RMSE_list_bin2=[]
train_RMSE_list_bin3=[]

# %%
#Dropping highly correlated features (correlation value > 0.99) from X data.
features =[
    'HAZ_rainfall_Total', 
    'HAZ_rainfall_max_6h',
    'HAZ_rainfall_max_24h',
    'HAZ_v_max',
    'HAZ_v_max_3',
    'HAZ_dis_track_min',
    'GEN_landslide_per',
    'GEN_stormsurge_per',
    #'GEN_Bu_p_inSSA', 
    #'GEN_Bu_p_LS', 
    'GEN_Red_per_LSbldg',
    'GEN_Or_per_LSblg', 
    'GEN_Yel_per_LSSAb', 
    #'GEN_RED_per_SSAbldg',
    'GEN_OR_per_SSAbldg',
    'GEN_Yellow_per_LSbl',
    'TOP_mean_slope',
    'TOP_mean_elevation_m', 
    'TOP_ruggedness_stdev', 
    #'TOP_mean_ruggedness',
    #'TOP_slope_stdev', 
    'VUL_poverty_perc',
    'GEN_with_coast',
    'GEN_coast_length', 
    'VUL_Housing_Units',
    'VUL_StrongRoof_StrongWall', 
    'VUL_StrongRoof_LightWall',
    'VUL_StrongRoof_SalvageWall', 
    'VUL_LightRoof_StrongWall',
    'VUL_LightRoof_LightWall', 
    'VUL_LightRoof_SalvageWall',
    'VUL_SalvagedRoof_StrongWall',
    'VUL_SalvagedRoof_LightWall',
    'VUL_SalvagedRoof_SalvageWall', 
    'VUL_vulnerable_groups',
    'VUL_pantawid_pamilya_beneficiary']
    
# Split X and y from dataframe features
X = df[features]
display(X.columns)
y = df["DAM_perc_dmg"]

scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)

def func(x):
    return np.log(x+1)+1

for i in range(20): 
    X_train, X_test, y_train, y_test = train_test_split(X_scaled,df['DAM_perc_dmg'], stratify=y_input_strat, test_size=0.2)

    
    bin_index_test=np.digitize(y_test, bins=binsP2)
    bin_index_train=np.digitize(y_train, bins=binsP2)
    
###You can test the performance by the following weighted RMSE
    
    #XGBoost Reduced Overfitting
    xgb = XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=0.8,
                       colsample_bynode=0.8, colsample_bytree=0.8, gamma=3, eta=0.01,
                       importance_type='gain', learning_rate=0.1, max_delta_step=0,
                       max_depth=4, min_child_weight=1, missing=1, n_estimators=100, early_stopping_rounds=10,
                       n_jobs=1, nthread=None, objective='reg:squarederror', random_state=0,
                       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
                       silent=None, subsample=0.8, verbosity=1, eval_metric=["rmse", "logloss"]
                     )

    
    eval_set = [(X_test, y_test)]
    xgb_model=xgb.fit(X_train, y_train, eval_set=eval_set, verbose=False, #sample_weight=y_train
    #                  sample_weight=np.log(y_train+1)+1
    #                  sample_weight=pow(y_train, 2)
                     )   
    
    #XGBoost
    #xgb = XGBRegressor(n_estimators=100, max_depth=4, learning_rate=0.1, gamma=1, reg_lambda=0.1, colsample_bytree=0.8)
    #xgb_model=xgb.fit(X_train, y_train, #sample_weight=y_train
    #                  sample_weight=np.log(y_train+1)+1
    #                  sample_weight=pow(y_train, 2)
    #                 )
    
    
    X2 = sm.add_constant(X_train)
    est = sm.OLS(y_train, X2)
    est2 = est.fit()
    print(est2.summary())
    
    y_pred_train = xgb.predict(X_train)
    mse_train_idx1 = mean_squared_error(y_train[bin_index_train==1], y_pred_train[bin_index_train==1])
    rmse_train_1 = np.sqrt(mse_train_idx1)
    mse_train_idx2 = mean_squared_error(y_train[bin_index_train==2], y_pred_train[bin_index_train==2])
    rmse_train_2 = np.sqrt(mse_train_idx2)
    mse_train_idx3 = mean_squared_error(y_train[bin_index_train==3], y_pred_train[bin_index_train==3])
    rmse_train_3 = np.sqrt(mse_train_idx3)
    

    y_pred = xgb.predict(X_test)
    mse_idx1 = mean_squared_error(y_test[bin_index_test==1], y_pred[bin_index_test==1])
    rmse_1 = np.sqrt(mse_idx1)
    mse_idx2 = mean_squared_error(y_test[bin_index_test==2], y_pred[bin_index_test==2])
    rmse_2 = np.sqrt(mse_idx2)
    mse_idx3 = mean_squared_error(y_test[bin_index_test==3], y_pred[bin_index_test==3])
    rmse_3 = np.sqrt(mse_idx3)

    
    
    print('----- Training_bins_RMSE  ------')
    print(f'Root mean squared error of bins_1: {rmse_train_1:.2f}')
    print(f'Root mean squared error of bins_2: {rmse_train_2:.2f}')
    print(f'Root mean squared error of bins_3: {rmse_train_3:.2f}')

    
    train_RMSE_list_bin1.append(rmse_train_1)
    train_RMSE_list_bin2.append(rmse_train_2)
    train_RMSE_list_bin3.append(rmse_train_3)
    
    
    print('----- Test_bins_RMSE  ------')
    print(f'Root mean squared error of bins_1: {rmse_1:.2f}')
    print(f'Root mean squared error of bins_2: {rmse_2:.2f}')
    print(f'Root mean squared error of bins_3: {rmse_3:.2f}')

    
    test_RMSE_list_bin1.append(rmse_1)
    test_RMSE_list_bin2.append(rmse_2)
    test_RMSE_list_bin3.append(rmse_3)
# Out:
# Index(['HAZ_rainfall_Total', 'HAZ_rainfall_max_6h', 'HAZ_rainfall_max_24h',
#        'HAZ_v_max', 'HAZ_v_max_3', 'HAZ_dis_track_min', 'GEN_landslide_per',
#        'GEN_stormsurge_per', 'GEN_Red_per_LSbldg', 'GEN_Or_per_LSblg',
#        'GEN_Yel_per_LSSAb', 'GEN_OR_per_SSAbldg', 'GEN_Yellow_per_LSbl',
#        'TOP_mean_slope', 'TOP_mean_elevation_m', 'TOP_ruggedness_stdev',
#        'VUL_poverty_perc', 'GEN_with_coast', 'GEN_coast_length',
#        'VUL_Housing_Units', 'VUL_StrongRoof_StrongWall',
#        'VUL_StrongRoof_LightWall', 'VUL_StrongRoof_SalvageWall',
#        'VUL_LightRoof_StrongWall', 'VUL_LightRoof_LightWall',
#        'VUL_LightRoof_SalvageWall', 'VUL_SalvagedRoof_StrongWall',
#        'VUL_SalvagedRoof_LightWall', 'VUL_SalvagedRoof_SalvageWall',
#        'VUL_vulnerable_groups', 'VUL_pantawid_pamilya_beneficiary'],
#       dtype='object')
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.412
# Model:                            OLS   Adj. R-squared:                  0.362
# Method:                 Least Squares   F-statistic:                     8.228
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           1.00e-26
# Time:                        01:06:28   Log-Likelihood:                -1681.4
# No. Observations:                 396   AIC:                             3427.
# Df Residuals:                     364   BIC:                             3554.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31
Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              194.264
# Skew:                           1.133   Prob(JB):                     6.55e-43
# Kurtosis:                       5.577   Cond. No.                     2.33e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 6.17
# Root mean squared error of bins_2: 5.31
# Root mean squared error of bins_3: 12.19
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 12.68
# Root mean squared error of bins_2: 12.94
# Root mean squared error of bins_3: 32.25
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.432
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     8.920
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           3.96e-29
# Time:                        01:06:30   Log-Likelihood:                -1667.8
# No. Observations:                 396   AIC:                             3400.
# Df Residuals:                     364   BIC:                             3527.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.2784      0.863     36.229      0.000      29.581      32.976
# x1            -9.8878      3.339     -2.962      0.003     -16.453      -3.322
# x2             3.6873      1.784      2.066      0.040       0.178       7.196
# x3             9.1704      3.943      2.326      0.021       1.416      16.925
# x4            -5.8334      4.305     -1.355      0.176     -14.300       2.633
# x5            15.0423      3.787      3.972      0.000       7.595      22.489
# x6             0.6113      1.642      0.372      0.710      -2.617       3.840
# x7          -676.9314    644.289     -1.051      0.294   -1943.927     590.064
# x8             0.8135      1.019      0.799      0.425      -1.190       2.817
# x9           206.1568    196.226      1.051      0.294    -179.722     592.035
# x10            2.5393      2.186      1.162      0.246      -1.759       6.838
# x11          583.9586    557.553      1.047      0.296    -512.470    1680.387
# x12            1.5276      1.027      1.488      0.138      -0.491       3.546
# x13           -1.3524      0.899     -1.504      0.133      -3.120       0.416
# x14           -4.0725      2.484     -1.640      0.102      -8.957       0.812
# x15            2.1256      1.710      1.243      0.215      -1.237       5.488
# x16            1.2902      2.132      0.605      0.546      -2.903       5.483
# x17           -5.7634      1.547     -3.725      0.000      -8.806      -2.721
# x18            1.7133      1.094      1.566      0.118      -0.438       3.865
# x19           -1.9567      1.036     -1.889      0.060      -3.994       0.081
# x20           -3.7577      1.101     -3.412      0.001      -5.923      -1.592
# x21            9.2680     35.747      0.259      0.796     -61.028      79.564
# x22           12.5427     36.449      0.344      0.731     -59.135      84.220
# x23            0.8058      2.325      0.347      0.729      -3.767       5.379
# x24            3.7899      9.170      0.413      0.680     -14.244      21.824
# x25            6.1985     34.017      0.182      0.856     -60.696      73.093
# x26            0.3322      1.531      0.217      0.828      -2.679       3.343
# x27           -1.1507      0.982     -1.171      0.242      -3.082       0.781
# x28            2.6273      1.369      1.919      0.056      -0.064       5.319
# x29            0.2859      1.588      0.180      0.857      -2.836       3.408
# x30            1.0429      1.312      0.795      0.427      -1.536       3.622
# x31           10.0921      1.242      8.123      0.000       7.649      12.535
# ==============================================================================
# Omnibus:                       67.719   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              134.477
# Skew:                           0.928   Prob(JB):                     6.29e-30
# Kurtosis:                       5.169   Cond. No.                     2.19e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 7.94
# Root mean squared error of bins_2: 7.56
# Root mean squared error of bins_3: 20.13
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 11.27
# Root mean squared error of bins_2: 11.11
# Root mean squared error of bins_3: 33.91
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     8.052
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           4.18e-26
# Time:                        01:06:31   Log-Likelihood:                -1677.7
# No. Observations:                 396   AIC:                             3419.
# Df Residuals:                     364   BIC:                             3547.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31
# x14           -1.5454      2.478     -0.624      0.533      -6.419       3.329
# x15            2.5164      1.763      1.427      0.154      -0.950       5.983
# x16           -0.6845      2.096     -0.327      0.744      -4.806       3.437
# x17           -6.0822      1.543     -3.941      0.000      -9.117      -3.047
# x18            1.9717      1.070      1.843      0.066      -0.132       4.075
# x19           -1.7670      1.046     -1.690      0.092      -3.823       0.289
# x20           -2.4725      1.104     -2.239      0.026      -4.644      -0.301
# x21           -0.5406     34.777     -0.016      0.988     -68.929      67.848
# x22            5.6308     35.484      0.159      0.874     -64.149      75.411
# x23           -2.3151      2.168     -1.068      0.286      -6.579       1.949
# x24            0.9724      8.922      0.109      0.913     -16.572      18.517
# x25           -1.9417     33.114     -0.059      0.953     -67.060      63.176
# x26            0.7557      1.429      0.529      0.597      -2.054       3.565
# x27           -0.7796      0.924     -0.843      0.400      -2.597       1.038
# x28            2.9115      1.142      2.549      0.011       0.665       5.158
# x29            0.4675      1.512      0.309      0.757      -2.507       3.442
# x30            0.6772      1.234      0.549      0.584      -1.750       3.105
# x31            9.8761      1.419      6.959      0.000       7.085      12.667
# ==============================================================================
# Omnibus:                       83.368   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              180.291
# Skew:                           1.089   Prob(JB):                     7.08e-40
# Kurtosis:                       5.487   Cond. No.                     2.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 6.58
# Root mean squared error of bins_2: 5.85
# Root mean squared error of bins_3: 14.95
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 14.43
# Root mean squared error of bins_2: 13.39
# Root mean squared error of bins_3: 32.51
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     9.149
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           6.55e-30
# Time:                        01:06:32   Log-Likelihood:                -1669.9
# No. Observations:                 396   AIC:                             3404.
# Df Residuals:                     364   BIC:                             3531.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.7544      0.866     36.654      0.000      30.051      33.458
# x1            -6.7999      3.163     -2.150      0.032     -13.019      -0.581
# x2             3.2933      1.740      1.893      0.059      -0.129       6.715
# x3             5.9836      3.861      1.550      0.122      -1.608      13.575
# x4            -8.9766      3.944     -2.276      0.023     -16.733      -1.220
# x5            17.2164      3.571      4.821      0.000      10.194      24.239
# x6            -1.2759      1.558     -0.819      0.413      -4.340       1.788
# x7         -1172.2183    677.732     -1.730      0.085   -2504.981     160.544
# x8             1.5213      1.022      1.489      0.137      -0.488       3.530
# x9           357.4555    206.496      1.731      0.084     -48.619     763.530
# x10            3.6540      2.338      1.563      0.119      -0.943       8.251
# x11         1012.3290    586.475      1.726      0.085    -140.975    2165.633
# x12            2.2811      0.863      2.643      0.009       0.584       3.979
# x13           -1.5517      0.885     -1.753      0.080      -3.293       0.189
# x14           -5.8168      2.611     -2.228      0.026     -10.951      -0.683
# x15            4.4846      1.902      2.358      0.019       0.745       8.225
# x16            0.3959      2.194      0.180      0.857      -3.919       4.711
# x17           -5.7907      1.600     -3.620      0.000      -8.936      -2.645
# x18            2.3876      1.113      2.146      0.033       0.199       4.576
# x19           -1.4208      1.081     -1.315      0.189      -3.546       0.704
# x20           -4.2667      1.058     -4.031      0.000      -6.348      -2.185
# x21           -2.8916     34.349     -0.084      0.933     -70.440      64.656
# x22            1.6145     34.982      0.046      0.963     -67.177      70.406
# x23            0.2991      2.160      0.138      0.890      -3.949       4.547
# x24            1.5149      8.782      0.173      0.863     -15.754      18.784
# x25           -4.6249     32.694     -0.141      0.888     -68.919      59.669
# x26            0.7133      1.502      0.475      0.635      -2.240       3.667
# x27           -0.9044      0.952     -0.950      0.343      -2.776       0.967
# x28            3.3493      1.232      2.720      0.007       0.927       5.771
# x29           -0.5921      1.659     -0.357      0.721      -3.854       2.670
# x30            1.2631      1.285      0.983      0.326      -1.264       3.790
# x31            9.3660      1.367      6.850      0.000       6.677      12.055
# ==============================================================================
# Omnibus:                       76.332   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              142.075
# Skew:                           1.069   Prob(JB):                     1.41e-31
# Kurtosis:                       5.009   Cond. No.                     2.27e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.27e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 5.59
# Root mean squared error of bins_2: 5.47
# Root mean squared error of bins_3: 11.21
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 18.29
# Root mean squared error of bins_2: 14.26
# Root mean squared error of bins_3: 25.83
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.435
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     9.053
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           1.39e-29
# Time:                        01:06:32   Log-Likelihood:                -1673.1
# No. Observations:                 396   AIC:                             3410.
# Df Residuals:                     364   BIC:                             3538.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.7864      0.875     36.326      0.000      30.066      33.507
# x1            -6.7571      3.332     -2.028      0.043     -13.309      -0.205
# x2             4.2708      1.857      2.300      0.022       0.620       7.922
# x3             3.4704      3.968      0.875      0.382      -4.333      11.274
# x4            -7.0576      3.918     -1.801      0.072     -14.762       0.647
# x5            15.5408      3.544      4.385      0.000       8.572      22.510
# x6            -0.4196      1.497     -0.280      0.779      -3.364       2.525
# x7          -703.1765    722.167     -0.974      0.331   -2123.320     716.968
# x8             0.7908      0.985      0.803      0.422      -1.145       2.727
# x9           215.8374    219.888      0.982      0.327    -216.573     648.248
# x10            2.1413      2.439      0.878      0.381      -2.655       6.938
# x11          606.8985    624.923      0.971      0.332    -622.014    1835.811
# x12            1.6202      1.026      1.578      0.115      -0.398       3.639
# x13           -2.0415      1.031     -1.979      0.049      -4.070      -0.013
# x14           -5.2098      2.532     -2.058      0.040     -10.188      -0.231
# x15            2.1599      1.771      1.219      0.224      -1.324       5.643
# x16            1.5336      2.140      0.717      0.474      -2.674       5.741
# x17           -6.1149      1.626     -3.760      0.000      -9.313      -2.917
# x18            2.4121      1.101      2.191      0.029       0.247       4.577
# x19           -1.9959      1.062     -1.879      0.061      -4.085       0.093
# x20           -3.2947      1.044     -3.157      0.002      -5.347      -1.243
# x21           38.6821     35.408      1.092      0.275     -30.947     108.311
# x22           44.2600     36.088      1.226      0.221     -26.707     115.227
# x23            1.8335      2.386      0.768      0.443      -2.859       6.526
# x24           11.2647      9.037      1.246      0.213      -6.508      29.037
# x25           35.4269     33.770      1.049      0.295     -30.983     101.836
# x26            2.6993      1.603      1.684      0.093      -0.453       5.852
# x27           -0.5498      0.941     -0.584      0.559      -2.400       1.301
# x28            2.6632      1.212      2.197      0.029       0.279       5.047
# x29            0.3103      1.550      0.200      0.841      -2.737       3.358
# x30            0.9594      1.364      0.703      0.482      -1.724       3.643
# x31           10.1218      1.326      7.635      0.000       7.515      12.729
# ==============================================================================
# Omnibus:                       78.591   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              173.336
# Skew:                           1.021   Prob(JB):                     2.29e-38
# Kurtosis:                       5.517   Cond. No.                     2.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 6.51
# Root mean squared error of bins_2: 6.26
# Root mean squared error of bins_3: 14.36
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 14.72
# Root mean squared error of bins_2: 12.92
# Root mean squared error of bins_3: 28.78
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.398
# Method:                 Least Squares   F-statistic:                     9.421
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           7.82e-31
# Time:                        01:06:33   Log-Likelihood:                -1663.1
# No. Observations:                 396   AIC:                             3390.
# Df Residuals:                     364   BIC:                             3518.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.5703      0.859     36.756      0.000      29.881      33.259
# x1            -7.0585      3.193     -2.211      0.028     -13.337      -0.780
# x2             2.8095      1.749      1.607      0.109      -0.629       6.248
# x3             6.0251      3.754      1.605      0.109      -1.356      13.407
# x4            -9.7703      3.959     -2.468      0.014     -17.555      -1.985
# x5            17.3662      3.589      4.839      0.000      10.308      24.424
# x6            -1.6521      1.485     -1.112      0.267      -4.573       1.268
# x7         -1031.3850    722.406     -1.428      0.154   -2451.998     389.228
# x8             0.6188      1.078      0.574      0.566      -1.500       2.738
# x9           314.8173    220.102      1.430      0.153    -118.015     747.649
# x10            2.5158      2.467      1.020      0.309      -2.336       7.368
# x11          890.2203    625.175      1.424      0.155    -339.187    2119.628
# x12            2.0003      0.934      2.141      0.033       0.163       3.838
# x13           -1.3304      0.893     -1.490      0.137      -3.087       0.426
# x14           -4.7417      2.570     -1.845      0.066      -9.795       0.312
# x15            2.5692      1.797      1.430      0.154      -0.964       6.102
# x16            2.4845      2.123      1.170      0.243      -1.690       6.659
# x17           -5.3968      1.588     -3.399      0.001      -8.519      -2.275
# x18            1.2904      1.081      1.194      0.233      -0.836       3.416
# x19           -1.0189      1.031     -0.988      0.324      -3.046       1.008
# x20           -3.4843      1.090     -3.196      0.002      -5.628      -1.340
# x21          -14.4557     35.028     -0.413      0.680     -83.339      54.428
# x22          -10.7842     35.661     -0.302      0.763     -80.911      59.343
# x23           -2.5795      2.135     -1.208      0.228      -6.778       1.620
# x24           -1.9018      8.969     -0.212      0.832     -19.539      15.735
# x25          -16.8410     33.329     -0.505      0.614     -82.383      48.701
# x26            0.6410      1.429      0.449      0.654      -2.169       3.451
# x27           -1.0868      0.923     -1.177      0.240      -2.902       0.729
# x28            2.2643      1.194      1.896      0.059      -0.084       4.613
# x29            1.0012      1.867      0.536      0.592      -2.670       4.673
# x30            1.4998      1.268      1.183      0.238      -0.993       3.993
# x31           10.4188      1.272      8.188      0.000       7.916      12.921
# ==============================================================================
# Omnibus:                       70.363   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              128.475
# Skew:                           1.000   Prob(JB):                     1.27e-28
# Kurtosis:                       4.946   Cond. No.                     2.40e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 6.90
# Root mean squared error of bins_2: 6.28
# Root mean squared error of bins_3: 14.41
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 14.17
# Root mean squared error of bins_2: 11.24
# Root mean squared error of bins_3: 32.09
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.382
# Method:                 Least Squares   F-statistic:                     8.885
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           5.22e-29
# Time:                        01:06:33   Log-Likelihood:                -1665.0
# No. Observations:                 396   AIC:                             3394.
# ...
# x19           -1.5724      1.112     -1.414      0.158      -3.760       0.615
# x20           -3.9024      1.102     -3.542      0.000      -6.069      -1.736
# x21           20.4368     32.401      0.631      0.529     -43.279      84.153
# x22           25.5630     33.053      0.773      0.440     -39.436      90.562
# x23            0.6936      2.013      0.345      0.731      -3.264       4.651
# x24            7.0880      8.322      0.852      0.395      -9.278      23.454
# x25           16.3000     30.843      0.528      0.597     -44.352      76.952
# x26            1.7654      1.431      1.233      0.218      -1.049       4.580
# x27           -0.9686      0.917     -1.056      0.292      -2.772       0.835
# x28            2.1474      1.157      1.856      0.064      -0.128       4.423
# x29           -0.1619      1.448     -0.112      0.911      -3.009       2.685
# x30            1.4150      1.307      1.083      0.280      -1.155       3.985
# x31           10.6974      1.367      7.825      0.000       8.009      13.386
# ==============================================================================
# Omnibus:                       76.684   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              146.943
# Skew:                           1.059   Prob(JB):                     1.24e-32
# Kurtosis:                       5.102   Cond. No.                     2.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 6.98
# Root mean squared error of bins_2: 6.20
# Root mean squared error of bins_3: 13.78
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 16.08
# Root mean squared error of bins_2: 12.76
# Root mean squared error of bins_3: 34.72
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.382
# Method:                 Least Squares   F-statistic:                     8.891
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           4.96e-29
# Time:                        01:06:37   Log-Likelihood:                -1679.8
# No. Observations:                 396   AIC:                             3424.
# Df Residuals:                     364   BIC:                             3551.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.8606      0.890     35.799      0.000      30.110      33.611
# x1            -5.9919      3.235     -1.852      0.065     -12.354       0.370
# x2             3.8147      1.805      2.114      0.035       0.266       7.364
# x3             4.0987      3.964      1.034      0.302      -3.697      11.894
# x4           -10.2211      4.063     -2.516      0.012     -18.211      -2.231
# x5            17.7723      3.643      4.878      0.000      10.608      24.937
# x6            -1.6305      1.593     -1.024      0.307      -4.762       1.501
# x7          -892.8129    680.857     -1.311      0.191   -2231.720     446.094
# x8             0.7604      0.999      0.761      0.447      -1.205       2.725
# x9           272.5330    207.302      1.315      0.189    -135.127     680.193
# x10            2.5665      2.291      1.120      0.263      -1.939       7.072
# x11          770.1036    589.184      1.307      0.192    -388.528    1928.735
# x12            1.5844      1.051      1.508      0.132      -0.482       3.651
# x13           -1.0110      0.885     -1.142      0.254      -2.752       0.730
# x14           -6.4626      2.660     -2.429      0.016     -11.694      -1.231
# x15            3.0883      1.749      1.766      0.078      -0.351       6.527
# x16            2.1675      2.257      0.960      0.338      -2.271       6.606
# x17           -6.4597      1.628     -3.967      0.000      -9.661      -3.258
# x18            2.1882      1.149      1.905      0.058      -0.071       4.447
# x19           -1.3464      1.179     -1.142      0.254      -3.665       0.972
# x20           -3.5579      1.170     -3.040      0.003      -5.860      -1.256
# x21          -10.5185     35.608     -0.295      0.768     -80.542      59.505
# x22           -7.0953     36.321     -0.195      0.845     -78.520      64.329
# x23           -1.2192      2.199     -0.554      0.580      -5.544       3.106
# x24           -0.4645      9.061     -0.051      0.959     -18.283      17.354
# x25          -12.6984     33.911     -0.374      0.708     -79.384      53.987
# x26            0.8115      1.442      0.563      0.574      -2.025       3.648
# x27           -1.1836      0.965     -1.227      0.221      -3.081       0.713
# x28            2.2769      1.195      1.906      0.057      -0.073       4.627
# x29           -0.1417      1.605     -0.088      0.930      -3.299       3.015
# x30            2.1837      1.319      1.655      0.099      -0.411       4.778
# x31           10.5436      1.268      8.314      0.000       8.050      13.038
# ==============================================================================
# Omnibus:                       71.176   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.124
# Skew:                           0.992   Prob(JB):                     4.55e-30
# Kurtosis:                       5.062   Cond. No.                     2.19e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 7.30
# Root mean squared error of bins_2: 6.61
# Root mean squared error of bins_3: 15.98
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 16.01
# Root mean squared error of bins_2: 12.49
# Root mean squared error of bins_3: 21.64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.368
# Method:                 Least Squares   F-statistic:                     8.425
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           2.03e-27
# Time:                        01:06:37   Log-Likelihood:                -1651.7
# No. Observations:                 396   AIC:                             3367.
# Df Residuals:                     364   BIC:                             3495.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.1195      0.828     37.562      0.000      29.490      32.749
# x1            -9.1640      3.051     -3.004      0.003     -15.164      -3.164
# x2             3.4988      1.683      2.079      0.038       0.189       6.809
# x3             7.5568      3.710      2.037      0.042       0.261      14.852
# x4            -8.7656      3.857     -2.272      0.024     -16.351      -1.180
# x5            17.6737      3.453      5.118      0.000      10.884      24.464
# x6            -0.6307      1.484     -0.425      0.671      -3.550       2.288
# x7          -506.3558    617.593     -0.820      0.413   -1720.853     708.142
# x8             0.4846      1.043      0.465      0.642      -1.566       2.535
# x9           153.4677    188.054      0.816      0.415    -216.342     523.277
# x10            1.4019      2.087      0.672      0.502      -2.702       5.505
# x11          436.6579    534.434      0.817      0.414    -614.307    1487.623
# x12            2.1210      0.881      2.408      0.017       0.389       3.853
# x13           -1.6858      0.851     -1.981      0.048      -3.359      -0.012
# x14           -1.8786      2.429     -0.773      0.440      -6.655       2.898
# x15            1.7745      1.812      0.980      0.328      -1.788       5.337
# x16            1.1517      1.974      0.583      0.560      -2.730       5.033
# x17           -5.9714      1.747     -3.417      0.001      -9.408      -2.535
# x18            1.7193      1.066      1.613      0.108      -0.377       3.816
# x19           -2.2489      1.036     -2.172      0.031      -4.285      -0.212
# x20           -3.0900      1.072     -2.883      0.004      -5.198      -0.982
# x21           14.5054     32.747      0.443      0.658     -49.893      78.903
# x22           17.0283     33.352      0.511      0.610     -48.559      82.615
# x23           -0.0716      2.200     -0.033      0.974      -4.398       4.255
# x24            4.3164      8.379      0.515      0.607     -12.161      20.794
# x25           11.1176     31.269      0.356      0.722     -50.372      72.607
# x26            0.7327      1.395      0.525      0.600      -2.010       3.476
# x27           -0.9820      0.894     -1.098      0.273      -2.740       0.776
# x28            2.4513      1.135      2.159      0.031       0.219       4.684
# x29            0.8666      1.503      0.577      0.565      -2.089       3.822
# x30            1.5784      1.268      1.245      0.214      -0.914       4.071
# x31           10.4948      1.590      6.601      0.000       7.368      13.621
# ==============================================================================
# Omnibus:                       55.272   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.267
# Skew:                           0.847   Prob(JB):                     1.52e-20
# Kurtosis:                       4.632   Cond. No.                     2.14e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 7.13
# Root mean squared error of bins_2: 6.68
# Root mean squared error of bins_3: 16.18
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 12.37
# Root mean squared error of bins_2: 12.20
# Root mean squared error of bins_3: 37.42
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DAM_perc_dmg   R-squared:                       0.394
# Model:                            OLS   Adj. R-squared:                  0.342
# Method:                 Least Squares   F-statistic:                     7.628
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):           1.34e-24
# Time:                        01:06:38   Log-Likelihood:                -1667.7
# No. Observations:                 396   AIC:                             3399.
# Df Residuals:                     364   BIC:                             3527.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.5905      0.862     36.654      0.000      29.896      33.285
# x1            -6.7078      3.227     -2.079      0.038     -13.054      -0.362
# x2             3.5212      1.744      2.019      0.044       0.091       6.951
# x3             5.5550      3.886      1.430      0.154      -2.086      13.196
# x4            -9.1617      3.909     -2.344      0.020     -16.849      -1.475
# x5            17.7865      3.554      5.004      0.000      10.797      24.776
# x6            -0.7634      1.506     -0.507      0.613      -3.726       2.199
# x7          -555.4109    698.941     -0.795      0.427   -1929.879     819.057
# x8             1.6413      1.357      1.210      0.227      -1.027       4.309
# x9           169.5738    212.883      0.797      0.426    -249.061     588.209
# x10            1.7328      2.430      0.713      0.476      -3.045       6.511
# x11          478.7702    604.818      0.792      0.429    -710.605    1668.146
# x12            2.3622      0.956      2.470      0.014       0.481       4.243
# x13           -1.3416      0.877     -1.529      0.127      -3.067       0.383
# x14           -3.9008      2.560     -1.524      0.128      -8.935       1.134
# x15            2.6972      1.796      1.502      0.134      -0.834       6.229
# x16            0.3525      2.176      0.162      0.871      -3.927       4.632
# x17           -5.6110      1.860     -3.016      0.003      -9.269      -1.953
# x18            2.2957      1.118      2.053      0.041       0.097       4.495
# x19           -1.2138      1.017     -1.193      0.234      -3.214       0.786
# x20           -3.3123      1.217     -2.723      0.007      -5.705      -0.920
# x21           -9.3824     34.896     -0.269      0.788     -78.005      59.241
# x22           -6.6063     35.419     -0.187      0.852     -76.257      63.044
# x23           -1.4361      2.177     -0.660      0.510      -5.716       2.844
# x24           -1.9717      8.875     -0.222      0.824     -19.424      15.480
# x25          -10.8894     33.242     -0.328      0.743     -76.260      54.481
# x26           -0.2786      1.468     -0.190      0.850      -3.165       2.608
# x27           -1.0342      0.934     -1.107      0.269      -2.872       0.803
# x28            2.0782      1.271      1.635      0.103      -0.422       4.578
# x29            0.9573      1.606      0.596      0.551      -2.201       4.115
# x30            1.8439      1.240      1.487      0.138      -0.594       4.282
# x31            9.4401      1.765      5.347      0.000       5.968      12.912
# ==============================================================================
# Omnibus:                       82.462   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              181.935
# Skew:                           1.069   Prob(JB):                     3.11e-40
# Kurtosis:                       5.541   Cond. No.                     2.39e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.39e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ----- Training_bins_RMSE  ------
# Root mean squared error of bins_1: 6.64
# Root mean squared error of bins_2: 6.31
# Root mean squared error of bins_3: 14.11
# ----- Test_bins_RMSE  ------
# Root mean squared error of bins_1: 15.23
# Root mean squared error of bins_2: 13.78
# Root mean squared error of bins_3: 31.64

# %%
#the End time of running the model 20 times
now = datetime.datetime.now()
print ("Current date and time : ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current date and time :
# 2022-11-10 01:06:38

# %%
#RMSE of bins_1

m_test_rmse = statistics.mean(test_RMSE_list_bin1)
plt.axvline(m_test_rmse, color='red', linestyle='dashed')
plt.hist(test_RMSE_list_bin1, bins=np.arange(10.0,22.0,0.7), edgecolor='k', histtype ='bar', density=True)
sd_test_rmse = statistics.stdev(test_RMSE_list_bin1)


m_train_rmse = statistics.mean(train_RMSE_list_bin1)
plt.axvline(m_train_rmse, color='b', linestyle='dashed')
plt.hist(train_RMSE_list_bin1, bins=np.arange(10.0,22.0,0.7), color='orange', edgecolor='k', histtype ='bar',
         density=True, alpha=0.7, #bins=np.arange(0.8,2.9,0.12)
        )
sd_train_rmse = statistics.stdev(train_RMSE_list_bin1)

print(f'stdev_RMSE_test: {sd_test_rmse:.2f}')
print(f'stdev_RMSE_train: {sd_train_rmse:.2f}')

print(f'mean_RMSE_test: {m_test_rmse:.2f}')
print(f'mean_RMSE_train: {m_train_rmse:.2f}')

#create legend
labels= ["Mean_test","Mean_train","test","train"]
plt.legend(labels)

plt.xlabel('The RMSE error')
plt.ylabel('Frequency')
plt.title('histogram of the RMSE distribution (bin1_(10.0, 20.0] )')
plt.show()
# Out:
# stdev_RMSE_test: 5.92
# stdev_RMSE_train: 7.54
# mean_RMSE_test: 19.72
# mean_RMSE_train: 13.90

# %%
#RMSE of bins_2

m_test_rmse = statistics.mean(test_RMSE_list_bin2)
plt.axvline(m_test_rmse, color='red', linestyle='dashed')
plt.hist(test_RMSE_list_bin2, bins=np.arange(5.0,17.0,0.7), edgecolor='k', histtype ='bar', density=True)
sd_test_rmse = statistics.stdev(test_RMSE_list_bin2)


m_train_rmse = statistics.mean(train_RMSE_list_bin2)
plt.axvline(m_train_rmse, color='b', linestyle='dashed')
plt.hist(train_RMSE_list_bin2, bins=np.arange(5.0,17.0,0.7), color='orange', edgecolor='k', histtype ='bar',
         density=True, alpha=0.7, #bins=np.arange(6.0,11.0,0.25)
        )
sd_train_rmse = statistics.stdev(train_RMSE_list_bin2)

print(f'stdev_RMSE_test: {sd_test_rmse:.2f}')
print(f'stdev_RMSE_train: {sd_train_rmse:.2f}')

print(f'mean_RMSE_test: {m_test_rmse:.2f}')
print(f'mean_RMSE_train: {m_train_rmse:.2f}')

#create legend
labels= ["Mean_test","Mean_train","test","train"]
plt.legend(labels)

plt.xlabel('The RMSE error')
plt.ylabel('Frequency')
plt.title('histogram of the RMSE distribution (bin2_(20.0, 50.0] )')
plt.show()
# Out:
# stdev_RMSE_test: 1.76
# stdev_RMSE_train: 2.06
# mean_RMSE_test: 13.11
# mean_RMSE_train: 8.01

# %%
#RMSE of bins_3

m_test_rmse = statistics.mean(test_RMSE_list_bin3)
plt.axvline(m_test_rmse, color='red', linestyle='dashed')
plt.hist(test_RMSE_list_bin3, bins=np.arange(3.0,42.0,2.1), edgecolor='k', histtype ='bar', density=True)
sd_test_rmse = statistics.stdev(test_RMSE_list_bin3)


m_train_rmse = statistics.mean(train_RMSE_list_bin3)
plt.axvline(m_train_rmse, color='b', linestyle='dashed')
plt.hist(train_RMSE_list_bin3, bins=np.arange(3.0,42.0,2.1), color='orange', edgecolor='k', histtype ='bar',
         density=True, alpha=0.7)
sd_train_rmse = statistics.stdev(train_RMSE_list_bin3)

print(f'stdev_RMSE_test: {sd_test_rmse:.2f}')
print(f'stdev_RMSE_train: {sd_train_rmse:.2f}')

print(f'mean_RMSE_test: {m_test_rmse:.2f}')
print(f'mean_RMSE_train: {m_train_rmse:.2f}')

#create legend
labels= ["Mean_test","Mean_train","test","train"]
plt.legend(labels)

plt.xlabel('The RMSE error')
plt.ylabel('Frequency')
plt.title('histogram of the RMSE distribution (bin3_(50.0, 100.0] )')
plt.show()
# Out:
# stdev_RMSE_test: 5.36
# stdev_RMSE_train: 2.97
# mean_RMSE_test: 28.25
# mean_RMSE_train: 11.54
