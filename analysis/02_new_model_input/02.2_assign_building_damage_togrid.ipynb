# %% [markdown]
# # Assignment of building damage data to grids from municipalities

# %% [markdown]
# This notebook that uses the weights from the area and the number of buildings.
# The rasterisation of damage data is done in this notebook.

# %%
# %load_ext jupyter_black
import pandas as pd
import os
from pathlib import Path

pd.set_option("display.float_format", lambda x: "%.5f" % x)
input_dir = (
    Path(os.getenv("STORM_DATA_DIR"))
    / "analysis/02_new_model_input/02_housing_damage/input/"
)
baseline_input_dir = (
    Path(os.getenv("STORM_DATA_DIR")) / "analysis/01_baseline_model/input/"
)
output_dir = (
    Path(os.getenv("STORM_DATA_DIR"))
    / "analysis/02_new_model_input/02_housing_damage/output/"
)
# Out:
# The jupyter_black extension is already loaded. To reload it, use:
#   %reload_ext jupyter_black

# %%
# reading in file with building damage data and adm3 in grid
adm3_perc_ingrid = pd.read_csv(
    input_dir / "Adm3_Perc_inGrid_Weight_Matrix.csv"
)
perc_build_dmg_data = pd.read_csv(
    baseline_input_dir / "combined_input_data.csv"
)
build_dmg_data = pd.read_csv(input_dir / "IMpact_data_philipines_SEP_2021.csv")
phl_build_weights = pd.read_csv(input_dir / "phl_bld_weight_matrix.csv")
phl_build_grid = pd.read_csv(
    input_dir / "phl_hotosm_bld_centroid_grid_count.csv"
)
phl_build_municip = pd.read_csv(
    input_dir / "phl_hotosm_bld_centroid_municip_count.csv"
)

# %%
# removing duplicates from the building damage data
# duplicates removed and kep only the first value for each municipality, typhoon and year
build_dmg_data.drop("Id", axis=1, inplace=True)
build_dmg_data.drop_duplicates(
    subset=["pcode", "typhoon", "Year"], inplace=True
)

# %%
build_dmg_data[build_dmg_data["pcode"] == "PH025012000"]
# Out:
#             pcode    typhoon  Year   Totally  Partially      total
# 740   PH025012000      Nesat  2011   1.00000    5.00000    6.00000
# 1227  PH025012000       Utor  2013   1.00000  104.00000  105.00000
# 1728  PH025012000  Fung-wong  2014  12.00000  149.00000  161.00000
# 1964  PH025012000       Goni  2015   0.00000   20.00000   20.00000
# 2114  PH025012000      Koppu  2015  22.00000  639.00000  661.00000
# 2355  PH025012000     Sarika  2016   1.00000   20.00000   21.00000
# 2560  PH025012000      Haima  2016   1.00000    1.00000    2.00000
# 2944  PH025012000   Mangkhut  2018   6.00000  211.00000  217.00000
# 3524  PH025012000       YUTU  2018   0.00000    8.00000    8.00000
# 3580  PH025012000   PHANFONE  2019 124.00000 1103.00000 1227.00000
# 3719  PH025012000    KAMMURI  2019   0.00000    2.00000    2.00000
# 4366  PH025012000      VAMCO  2020   2.00000   94.00000   96.00000

# %% [markdown]
# We will come back to this
# as it is not clear why there are multiple rows for the same municipalities
# recorded for the same typhoon and Year in the building damage data set.
# Different total values could be accumulations. For now, treating them as separate values.

# %%
## aggregating these values
## To confirm whether they are additional data or cumulative data in the case where the total values are different for same typhoons.

# build_dmg_data_grouped = (
#    build_dmg_data.groupby(["pcode", "typhoon", "Year"]).sum().reset_index()
# )
# build_dmg_data_grouped[build_dmg_data_grouped["pcode"] == "PH025012000"]

# %%
all(
    item in list(phl_build_municip["ADM3_PCODE"])
    for item in list(build_dmg_data["pcode"])
)
# Not all municipalities are in the damage data set.
# Not all municipalities in the building damage data can be found in the admin 3 shapefile.
# removing those buildings with incorrect pcode in them
build_dmg_data_grouped = build_dmg_data[
    build_dmg_data["pcode"].isin(list(phl_build_municip["ADM3_PCODE"]))
]
build_dmg_data_grouped["Totally"].sum()
# Out:
# 1670866.0

# %% [markdown]
# ## Using Area of Municipality

# %%
## Section describing the merging of the north and south buildings from HOTOSM shapefile
merged_df_points = phl_build_grid.copy()
merged_df_points = pd.merge(
    merged_df_points,
    phl_build_grid.drop("numbuildings", axis=1),
    on="id",
    suffixes=(None, "_y"),
)

merged_df_points["numbuildings"].describe()
# Out:
# count     3352.00000
# mean      3084.21002
# std      12590.52975
# min          1.00000
# 25%         78.00000
# 50%        395.00000
# 75%       1913.00000
# max     302704.00000
# Name: numbuildings, dtype: float64

# %%
merged_df_points_overlap = merged_df_points.loc[
    merged_df_points["Centroid"].isin(adm3_perc_ingrid["Centroid"])
]

# %%
### Section describing the computation of the building damage percentage
# combining building damage data and grid information
merged_total_damage_df = adm3_perc_ingrid.merge(
    build_dmg_data_grouped,
    left_on="ADM3_PCODE",
    right_on="pcode",
    how="left",
)

# %%
# computing % in each grid
# totally damaged
merged_total_damage_df["Totally_Damaged_bygrid"] = (
    merged_total_damage_df["Municipality Completeness"]
    * merged_total_damage_df["Totally"]
)

# %%
merged_total_damage_df[
    (merged_total_damage_df["pcode"] == "PH025012000")
    & (merged_total_damage_df["typhoon"] == "Mangkhut")
]
# Out:
#           id      Centroid   ADM3_PCODE   ADM3_EN  Municipality Completeness  \
# 25526  10904  120.8E_16.3N  PH025012000  Santa Fe                    0.00794
# 25538  10905  120.8E_16.2N  PH025012000  Santa Fe                    0.23855
# 25550  10906  120.8E_16.1N  PH025012000  Santa Fe                    0.00002
# 25562  11072  120.9E_16.2N  PH025012000  Santa Fe                    0.38775
# 25574  11073  120.9E_16.1N  PH025012000  Santa Fe                    0.10163
# 25586  11239  121.0E_16.2N  PH025012000  Santa Fe                    0.17268
# 25598  11240  121.0E_16.1N  PH025012000  Santa Fe                    0.07625
# 25610  11406  121.1E_16.2N  PH025012000  Santa Fe                    0.00336
# 25622  11407  121.1E_16.1N  PH025012000  Santa Fe                    0.01180
#
#              pcode   typhoon       Year  Totally  Partially     total  \
# 25526  PH025012000  Mangkhut 2018.00000  6.00000  211.00000 217.00000
# 25538  PH025012000  Mangkhut 2018.00000  6.00000  211.00000 217.00000
# 25550  PH025012000  Mangkhut 2018.00000  6.00000  211.00000 217.00000
# 25562  PH025012000  Mangkhut 2018.00000  6.00000  211.00000 217.00000
# 25574  PH025012000  Mangkhut 2018.00000  6.00000  211.00000 217.00000
# 25586  PH025012000  Mangkhut 2018.00000  6.00000  211.00000 217.00000
# 25598  PH025012000  Mangkhut 2018.00000  6.00000  211.00000 217.00000
# 25610  PH025012000  Mangkhut 2018.00000  6.00000  211.00000 217.00000
# 25622  PH025012000  Mangkhut 2018.00000  6.00000  211.00000 217.00000
#
#        Totally_Damaged_bygrid
# 25526                 0.04765
# 25538                 1.43128
# 25550                 0.00013
# 25562                 2.32653
# 25574                 0.60980
# 25586                 1.03610
# 25598                 0.45751
# 25610                 0.02019
# 25622                 0.07081

# %%
test_df = (
    merged_total_damage_df[["ADM3_PCODE", "Totally_Damaged_bygrid"]]
    .groupby("ADM3_PCODE")
    .sum()
    .reset_index()
    .merge(
        build_dmg_data_grouped[["pcode", "Totally"]]
        .groupby("pcode")
        .sum()
        .reset_index(),
        left_on="ADM3_PCODE",
        right_on="pcode",
        how="left",
    )
)
test_df["Diff"] = test_df["Totally_Damaged_bygrid"] - test_df["Totally"]
test_df["Diff"].describe()
# Out:
# count   1263.00000
# mean      -0.00004
# std        0.00141
# min       -0.04138
# 25%       -0.00000
# 50%        0.00000
# 75%        0.00000
# max        0.00795
# Name: Diff, dtype: float64

# %% [markdown]
# A small difference between the number of totally damaged values.
# This can be explained by the weighting using the area overlap.
# There may be some rounding when computing the area.

# %%
# computing percentage damage
# merging with building damage data
merged_perc_damage_df = merged_df_points.merge(
    merged_total_damage_df, on="id", how="right", suffixes=(None, "_y")
)
merged_perc_damage_df[
    [
        "id",
        "Centroid",
        "ADM3_PCODE",
        "ADM3_EN",
        "typhoon",
        "Year",
        "Municipality Completeness",
        "Totally",
        "numbuildings",
        "Totally_Damaged_bygrid",
    ]
].sort_values(["Totally_Damaged_bygrid"], ascending=False)
# Out:
#           id      Centroid   ADM3_PCODE       ADM3_EN typhoon       Year  \
# 19236  15273  123.4E_13.6N  PH051725000        Ocampo  Durian 2006.00000
# 9136   16299  124.0E_11.2N  PH072221000  Daanbantayan  Haiyan 2013.00000
# 19836  17969  125.0E_11.2N  PH083739000          Palo  Haiyan 2013.00000
# 3069   15798  123.7E_11.2N  PH072209000      Bantayan  Haiyan 2013.00000
# 27737  17970  125.0E_11.1N  PH083748000       Tanauan  Haiyan 2013.00000
# ...      ...           ...          ...           ...     ...        ...
# 29505  14815   123.1E_9.3N  PH074625000  Zamboanguita     NaN        NaN
# 29506  14816   123.1E_9.2N  PH074625000  Zamboanguita     NaN        NaN
# 29507  14817   123.1E_9.1N  PH074625000  Zamboanguita     NaN        NaN
# 29508  14983   123.2E_9.2N  PH074625000  Zamboanguita     NaN        NaN
# 29509  14984   123.2E_9.1N  PH074625000  Zamboanguita     NaN        NaN
#
#        Municipality Completeness     Totally  numbuildings  \
# 19236                    0.73242 25951.00000     381.00000
# 9136                     0.67517 13660.00000   13825.00000
# 19836                    0.51789 13481.00000   48718.00000
# 3069                     0.59869 10533.00000   10951.00000
# 27737                    0.90848  6670.00000   10487.00000
# ...                          ...         ...           ...
# 29505                    0.00045         NaN      39.00000
# 29506                    0.26854         NaN     111.00000
# 29507                    0.09097         NaN     416.00000
# 29508                    0.31341         NaN     127.00000
# 29509                    0.32663         NaN      79.00000
#
#        Totally_Damaged_bygrid
# 19236             19007.06995
# 9136               9222.79095
# 19836              6981.66883
# 3069               6305.98698
# 27737              6059.56721
# ...                       ...
# 29505                     NaN
# 29506                     NaN
# 29507                     NaN
# 29508                     NaN
# 29509                     NaN
#
# [29556 rows x 10 columns]

# %% [markdown]
# We changed the approach to use number of buildings in a municipality instead.
# Since we are using HOTOSM data, which is differently sourced from the damage data,
# some municipalities and grids have more damaged buildings than total number of buildings.
# TODO: Find new building dataset that is more accurate.

# %%
merged_perc_damage_dfout = (
    merged_perc_damage_df[
        [
            "id",
            "Centroid",
            "ADM3_PCODE",
            "ADM3_EN",
            "typhoon",
            "Year",
            "numbuildings",
            "Totally_Damaged_bygrid",
        ]
    ]
    .groupby(["id", "Centroid", "typhoon", "Year"])
    .sum(numeric_only=True)
    .reset_index()
)
# computing the percentage damage
merged_perc_damage_dfout["Totally_Damaged_Perc_bygrid"] = (
    merged_perc_damage_dfout["Totally_Damaged_bygrid"]
    / merged_perc_damage_dfout["numbuildings"]
)
merged_perc_damage_dfout.sort_values(
    ["Totally_Damaged_Perc_bygrid"], ascending=False
)
# Out:
#           id      Centroid   typhoon       Year  numbuildings  \
# 12985  20007   126.2E_7.8N     Bopha 2012.00000       8.00000
# 12267  18468  125.3E_11.4N  Fengshen 2008.00000       4.00000
# 12992  20009   126.2E_7.6N     Bopha 2012.00000      12.00000
# 12269  18468  125.3E_11.4N    Haiyan 2013.00000       4.00000
# 4988   11772  121.3E_13.0N     Melor 2015.00000      24.00000
# ...      ...           ...       ...        ...           ...
# 2732   11048  120.9E_18.6N     VAMCO 2020.00000    1334.00000
# 2726   11048  120.9E_18.6N  Kalmaegi 2014.00000    1334.00000
# 2717   10940  120.8E_12.7N     NAKRI 2019.00000      28.00000
# 2711   10939  120.8E_12.8N     NAKRI 2019.00000     157.00000
# 0       6299   118.0E_9.2N     LINFA 2015.00000      57.00000
#
#        Totally_Damaged_bygrid  Totally_Damaged_Perc_bygrid
# 12985              2280.68599                    285.08575
# 12267               806.32677                    201.58169
# 12992              1759.18131                    146.59844
# 12269               573.66872                    143.41718
# 4988               2916.54911                    121.52288
# ...                       ...                          ...
# 2732                  0.00000                      0.00000
# 2726                  0.00000                      0.00000
# 2717                  0.00000                      0.00000
# 2711                  0.00000                      0.00000
# 0                     0.00000                      0.00000
#
# [13144 rows x 7 columns]

# %%
merged_perc_damage_dfout["Totally_Damaged_bygrid"].sum()
# Out:
# 1645927.7189275506

# %%
# writing output to CSV file
# to write to csv file, group first by grid centroid
merged_perc_damage_dfout.to_csv(
    output_dir / "building_damage_bygrid_using_area.csv", index=False
)

# %% [markdown]
# ## Using Number of Buildings

# %% [markdown]
# Merging all dataframes, one with number of buildings in municipality,
# one with number of damaged buildings in municipality and
# the last with weights for each grid and municipality.

# %%
phl_bld_all_merged_df = phl_build_municip.merge(
    build_dmg_data_grouped,
    left_on="ADM3_PCODE",
    right_on="pcode",
    how="left",
    suffixes=(None, "_y"),
).merge(phl_build_weights, on="ADM3_PCODE", how="left", suffixes=(None, "_y"))

# %%
phl_bld_all_merged_df[phl_bld_all_merged_df["ADM3_PCODE"] == "PH175301000"]
# Out:
#     Unnamed: 0  Shape_Leng  Shape_Area  ADM3_EN   ADM3_PCODE ADM3_REF  \
# 0            0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 1            0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 2            0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 3            0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 4            0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 5            0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 6            0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 7            0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 8            0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 9            0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 10           0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 11           0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 12           0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 13           0     1.60122     0.06350  Aborlan  PH175301000      NaN
# 14           0     1.60122     0.06350  Aborlan  PH175301000      NaN
#
#     ADM3ALT1EN  ADM3ALT2EN  ADM2_EN   ADM2_PCODE  ... typhoon Year Totally  \
# 0          NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 1          NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 2          NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 3          NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 4          NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 5          NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 6          NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 7          NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 8          NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 9          NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 10         NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 11         NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 12         NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 13         NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
# 14         NaN         NaN  Palawan  PH175300000  ...     NaN  NaN     NaN
#
#    Partially total Unnamed: 0_y  ADM3_EN_y         id     Centroid  weight
# 0        NaN   NaN            0    Aborlan 6795.00000  118.3E_9.7N 0.00000
# 1        NaN   NaN            1    Aborlan 6796.00000  118.3E_9.6N 0.00499
# 2        NaN   NaN            2    Aborlan 6797.00000  118.3E_9.5N 0.00449
# 3        NaN   NaN            3    Aborlan 6798.00000  118.3E_9.4N 0.00000
# 4        NaN   NaN            4    Aborlan 6962.00000  118.4E_9.7N 0.15254
# 5        NaN   NaN            5    Aborlan 6963.00000  118.4E_9.6N 0.02742
# 6        NaN   NaN            6    Aborlan 6964.00000  118.4E_9.5N 0.00000
# 7        NaN   NaN            7    Aborlan 6965.00000  118.4E_9.4N 0.00000
# 8        NaN   NaN            8    Aborlan 7130.00000  118.5E_9.6N 0.00000
# 9        NaN   NaN            9    Aborlan 7131.00000  118.5E_9.5N 0.02692
# 10       NaN   NaN           10    Aborlan 7132.00000  118.5E_9.4N 0.06979
# 11       NaN   NaN           11    Aborlan 7133.00000  118.5E_9.3N 0.00050
# 12       NaN   NaN           12    Aborlan 7297.00000  118.6E_9.6N 0.00000
# 13       NaN   NaN           13    Aborlan 7298.00000  118.6E_9.5N 0.32004
# 14       NaN   NaN           14    Aborlan 7299.00000  118.6E_9.4N 0.39332
#
# [15 rows x 30 columns]

# %%
phl_build_weights.groupby("ADM3_PCODE")["weight"].sum().describe()
# Out:
# count   1647.00000
# mean       0.99636
# std        0.06027
# min        0.00000
# 25%        1.00000
# 50%        1.00000
# 75%        1.00000
# max        1.00000
# Name: weight, dtype: float64

# %%
phl_bld_all_merged_df.groupby(["pcode", "typhoon", "Year"]).first()[
    "Totally"
].sum()
# Out:
# 1670866.0

# %%
phl_bld_all_merged_df.groupby(["pcode", "typhoon", "Year"]).first()[
    "numbuildings"
].sum()
# Out:
# 31001690

# %%
phl_build_municip["numbuildings"].sum()
# Out:
# 10324006

# %%
phl_bld_all_merged_df["numbuildings_bygrid"] = (
    phl_bld_all_merged_df["weight"] * phl_bld_all_merged_df["numbuildings"]
)
phl_bld_all_merged_df["Totally_Damaged_bygrid"] = (
    phl_bld_all_merged_df["weight"] * phl_bld_all_merged_df["Totally"]
)
phl_bld_all_merged_df["Totally_Damaged_bygrid"] = phl_bld_all_merged_df[
    "Totally_Damaged_bygrid"
].fillna(0)
phl_bld_all_merged_df[
    [
        "id",
        "Centroid",
        "ADM3_PCODE",
        "typhoon",
        "Year",
        "weight",
        "Totally",
        "numbuildings",
        "numbuildings_bygrid",
        "Totally_Damaged_bygrid",
    ]
].sort_values(["Totally_Damaged_bygrid"], ascending=False)
# Out:
#                id      Centroid   ADM3_PCODE   typhoon       Year  weight  \
# 19222 15273.00000  123.4E_13.6N  PH051725000    Durian 2006.00000 0.76867
# 19834 17969.00000  125.0E_11.2N  PH083739000    Haiyan 2013.00000 0.80034
# 27352 17969.00000  125.0E_11.2N  PH083747000    Haiyan 2013.00000 0.72317
# 9144  16299.00000  124.0E_11.2N  PH072221000    Haiyan 2013.00000 0.52432
# 19398 17303.00000  124.6E_11.0N  PH083738000    Haiyan 2013.00000 0.49538
# ...           ...           ...          ...       ...        ...     ...
# 18201 15783.00000  123.7E_12.7N  PH054114000     Melor 2015.00000 0.00000
# 5245  14604.00000  123.0E_13.7N  PH051707000  Rammasun 2014.00000 0.00000
# 18203 15616.00000  123.6E_12.7N  PH054114000    Haiyan 2013.00000 0.00000
# 18204 15617.00000  123.6E_12.6N  PH054114000    Haiyan 2013.00000 0.33427
# 0      6795.00000   118.3E_9.7N  PH175301000       NaN        NaN 0.00000
#
#           Totally  numbuildings  numbuildings_bygrid  Totally_Damaged_bygrid
# 19222 25951.00000           415            319.00000             19947.87711
# 19834 13481.00000         10588           8474.00000             10789.38364
# 27352 12270.00000         55565          40183.00000              8873.30892
# 9144  13660.00000         20701          10854.00000              7162.24530
# 19398 14132.00000         30865          15290.00000              7000.75425
# ...           ...           ...                  ...                     ...
# 18201   964.00000          1430              0.00000                 0.00000
# 5245    696.00000          1815              0.00000                 0.00000
# 18203     0.00000          1430              0.00000                 0.00000
# 18204     0.00000          1430            478.00000                 0.00000
# 0             NaN          2006              0.00000                 0.00000
#
# [29556 rows x 10 columns]

# %%
phl_bld_all_merged_df[phl_bld_all_merged_df["ADM3_PCODE"] == "PH025012000"][
    [
        "id",
        "Centroid",
        "ADM3_PCODE",
        "typhoon",
        "Year",
        "weight",
        "Totally",
        "numbuildings",
        "numbuildings_bygrid",
        "Totally_Damaged_bygrid",
    ]
]
# Out:
#                id      Centroid   ADM3_PCODE typhoon       Year  weight  \
# 25519 11072.00000  120.9E_16.2N  PH025012000   Nesat 2011.00000 0.22449
# 25520 11239.00000  121.0E_16.2N  PH025012000   Nesat 2011.00000 0.05306
# 25521 11406.00000  121.1E_16.2N  PH025012000   Nesat 2011.00000 0.00000
# 25522 11407.00000  121.1E_16.1N  PH025012000   Nesat 2011.00000 0.00000
# 25523 10904.00000  120.8E_16.3N  PH025012000   Nesat 2011.00000 0.00000
# ...           ...           ...          ...     ...        ...     ...
# 25622 10904.00000  120.8E_16.3N  PH025012000   VAMCO 2020.00000 0.00000
# 25623 11073.00000  120.9E_16.1N  PH025012000   VAMCO 2020.00000 0.04082
# 25624 11240.00000  121.0E_16.1N  PH025012000   VAMCO 2020.00000 0.02041
# 25625 10905.00000  120.8E_16.2N  PH025012000   VAMCO 2020.00000 0.66122
# 25626 10906.00000  120.8E_16.1N  PH025012000   VAMCO 2020.00000 0.00000
#
#        Totally  numbuildings  numbuildings_bygrid  Totally_Damaged_bygrid
# 25519  1.00000           245             55.00000                 0.22449
# 25520  1.00000           245             13.00000                 0.05306
# 25521  1.00000           245              0.00000                 0.00000
# 25522  1.00000           245              0.00000                 0.00000
# 25523  1.00000           245              0.00000                 0.00000
# ...        ...           ...                  ...                     ...
# 25622  2.00000           245              0.00000                 0.00000
# 25623  2.00000           245             10.00000                 0.08163
# 25624  2.00000           245              5.00000                 0.04082
# 25625  2.00000           245            162.00000                 1.32245
# 25626  2.00000           245              0.00000                 0.00000
#
# [108 rows x 10 columns]

# %%
phl_bld_all_merged_df["Totally_Damaged_bygrid"].sum()
# Out:
# 1669643.9999999995

# %%
phl_bld_all_merged_df["numbuildings_bygrid"].sum()
# Out:
# 32311224.0

# %%
phl_bld_all_merged_dfout = phl_bld_all_merged_df[
    [
        "id",
        "Centroid",
        "typhoon",
        "Year",
        "weight",
        "numbuildings_bygrid",
        "Totally_Damaged_bygrid",
    ]
]
phl_bld_all_merged_dfout = (
    phl_bld_all_merged_dfout.groupby(["id", "Centroid", "typhoon", "Year"])
    .sum()
    .reset_index()
)

phl_bld_all_merged_dfout["Totally_Damaged_Perc_bygrid"] = (
    phl_bld_all_merged_dfout["Totally_Damaged_bygrid"]
    / phl_bld_all_merged_dfout["numbuildings_bygrid"]
)
phl_bld_all_merged_dfout.sort_values(
    ["Totally_Damaged_Perc_bygrid"], ascending=False
)
# Out:
#                id      Centroid   typhoon       Year  weight  \
# 10095 15273.00000  123.4E_13.6N    Durian 2006.00000 0.88814
# 14052 20339.00000   126.4E_8.0N     Bopha 2012.00000 0.23171
# 14049 20338.00000   126.4E_8.1N     Bopha 2012.00000 0.67995
# 5461  11780.00000  121.3E_12.2N  PHANFONE 2019.00000 0.01299
# 5456  11779.00000  121.3E_12.3N  PHANFONE 2019.00000 0.58442
# ...           ...           ...       ...        ...     ...
# 14088 20505.00000   126.5E_8.1N    Haiyan 2013.00000 0.00000
# 14089 20505.00000   126.5E_8.1N  Lingling 2014.00000 0.00000
# 14111 20516.00000   126.5E_7.0N     Bopha 2012.00000 0.00000
# 14112 20516.00000   126.5E_7.0N    Haiyan 2013.00000 0.00000
# 14113 20516.00000   126.5E_7.0N  Lingling 2014.00000 0.00000
#
#        numbuildings_bygrid  Totally_Damaged_bygrid  \
# 10095            381.00000             20770.12374
# 14052             19.00000               846.19512
# 14049             64.00000              2454.81445
# 5461               1.00000                34.51948
# 5456              45.00000              1553.37662
# ...                    ...                     ...
# 14088              0.00000                 0.00000
# 14089              0.00000                 0.00000
# 14111              0.00000                 0.00000
# 14112              0.00000                 0.00000
# 14113              0.00000                 0.00000
#
#        Totally_Damaged_Perc_bygrid
# 10095                     54.51476
# 14052                     44.53659
# 14049                     38.35648
# 5461                      34.51948
# 5456                      34.51948
# ...                            ...
# 14088                          NaN
# 14089                          NaN
# 14111                          NaN
# 14112                          NaN
# 14113                          NaN
#
# [14128 rows x 8 columns]

# %%
phl_bld_all_merged_dfout["numbuildings_bygrid"].sum()
# Out:
# 31001690.0

# %%
phl_bld_all_merged_dfout[phl_bld_all_merged_dfout["Centroid"] == "126.6E_7.3N"]
# Out:
#                id     Centroid   typhoon       Year  weight  \
# 14122 20680.00000  126.6E_7.3N     Bopha 2012.00000 0.47503
# 14123 20680.00000  126.6E_7.3N    Haiyan 2013.00000 0.01795
# 14124 20680.00000  126.6E_7.3N  Lingling 2014.00000 0.47503
#
#        numbuildings_bygrid  Totally_Damaged_bygrid  \
# 14122            401.00000               923.35933
# 14123              7.00000                 0.05385
# 14124            401.00000                27.02136
#
#        Totally_Damaged_Perc_bygrid
# 14122                      2.30264
# 14123                      0.00769
# 14124                      0.06738

# %%
phl_bld_all_merged_dfout.groupby(["Centroid"])[
    "numbuildings_bygrid"
].sum().reset_index()
# Out:
#          Centroid  numbuildings_bygrid
# 0     117.9E_9.0N              0.00000
# 1     117.9E_9.1N              0.00000
# 2     118.0E_8.9N              2.00000
# 3     118.0E_9.0N            379.00000
# 4     118.0E_9.1N              0.00000
# ...           ...                  ...
# 2989  126.6E_7.3N            809.00000
# 2990  126.6E_7.4N             26.00000
# 2991  126.6E_7.5N             88.00000
# 2992  126.6E_7.6N            346.00000
# 2993  126.6E_7.7N             24.00000
#
# [2994 rows x 2 columns]

# %%
phl_bld_all_merged_dfout["Totally_Damaged_bygrid"].sum()
# Out:
# 1669643.9999999998

# %%
phl_bld_all_merged_dfout["Totally_Damaged_Perc_bygrid"].describe()
# Out:
# count   12228.00000
# mean        0.25820
# std         1.55548
# min         0.00000
# 25%         0.00045
# 50%         0.00614
# 75%         0.06833
# max        54.51476
# Name: Totally_Damaged_Perc_bygrid, dtype: float64

# %%
# writing output to CSV file
# to write to csv file, group first by grid centroid
phl_bld_all_merged_dfout.to_csv(
    output_dir / "building_damage_bygrid.csv", index=False
)
